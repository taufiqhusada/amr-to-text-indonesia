# %% [markdown]
# # AMR Silver Data Creation
# Steps:
# 1. get 200k sentences from Indo4b corpus
# 2. generate amr from those sentences using AMR parser
#
# note: this notebook is created using google colab

# %% [markdown]
# ## Get 200k sentences from Indo4b corpus
# - note: only get formal indonesian sentences (e.g: news articles)

# %%
# !wget https://storage.googleapis.com/babert-pretraining/IndoNLU_finals/dataset/preprocessed/dataset_wot_uncased_blanklines.tar.xz
# Out:
# --2022-01-18 09:01:08--  https://storage.googleapis.com/babert-pretraining/IndoNLU_finals/dataset/preprocessed/dataset_wot_uncased_blanklines.tar.xz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.145.128, 74.125.143.128, 173.194.69.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.145.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6017328328 (5.6G) [application/x-tar]
# Saving to: ‘dataset_wot_uncased_blanklines.tar.xz’
#
# dataset_wot_uncased 100%[===================>]   5.60G  33.6MB/s    in 1m 54s
#
# 2022-01-18 09:03:03 (50.4 MB/s) - ‘dataset_wot_uncased_blanklines.tar.xz’ saved [6017328328/6017328328]

# %%
# !tar -xf dataset_wot_uncased_blanklines.tar.xz

# %%
# !ls /content/processed_uncased_blanklines
# Out:
# bppt.txt		kompas.txt	       talpco_indonesia.txt
# conllu_all_uncased.txt	opensubtitles.txt      tempo.txt
# frog_storytelling.txt	oscar_all_uncased.txt  wikipedia_conllu.txt
# jw300.txt		parallel_corpus.txt    wiki.txt

# %%
FOLDER_PATH = '/content/processed_uncased_blanklines'

# %%
import os
import random
import math

# %%
list_sentences_from_tempo = []
with open(os.path.join(FOLDER_PATH, 'tempo.txt')) as f:
  for _ in range(5):
    sent = f.readline()
    print(f'length: {len(sent)}', ' | ',  f'sentence: {sent}')
# Out:
# length: 76  |  sentence: partai persatuan bangsa adalah partai yang telah memperoleh nur dari allah.
#
# length: 111  |  sentence: partai ini pulalah yang benar-benar dilahirkan oleh para ulama dan fusi dari partai-partai islam di indonesia.
#
# length: 176  |  sentence: hal itu disampaikan ketua umum ppp hamzah haz dalam sambutannya dalam perayaan hari lahir (harlah) partai itu yang ke-29 di gelora bung karno, senayan, jakarta, minggu (21/4).
#
# length: 1  |  sentence:
#
# length: 163  |  sentence: di hadapan puluhan ribu pedukungnya, hamzah haz yang saat ini menjadi orang nomor dua di republik ini menegaskan, ppp sampai saat ini masih tetap kukuh dan besar.

# %%
def get_sentences_from_corpus(file_path, cnt_sentences = 100000, max_iter = 1000000, min_len = 1, max_len=384):
  # get some sentences from corpus
  file_size = os.path.getsize(file_path)
  max_iter = min(max_iter, file_size)
  list_sentences = []
  cnt = 0
  with open(file_path) as f:
    for _ in range(file_size):
      if (cnt==max_iter):
        break

      sent = f.readline()
      if ("'" not in sent and '"' not in sent and len(sent)>=min_len and len(sent)<=max_len and len(sent.split())>=2):
        list_sentences.append(sent.strip())
        cnt += 1
  
  # choose sentences in a uniform distribution
  cnt_sentences = min(cnt_sentences, len(list_sentences)-1)
  step = math.floor(len(list_sentences) / cnt_sentences)
  list_chosen_idx_sent = []
  cnt = 0
  for i in range(0, len(list_sentences), step):
    list_chosen_idx_sent.append(i)
    cnt+=1
    if (cnt==cnt_sentences):
      break

  random.shuffle(list_chosen_idx_sent)
  print(list_chosen_idx_sent[0:10])
  final_list_sentences =  [list_sentences[i] for i in list_chosen_idx_sent]

  return final_list_sentences

# %% [markdown]
# ### Get 100k sentences from indo4b tempo (news article from Tempo)

# %%
list_sentences = get_sentences_from_corpus(os.path.join(FOLDER_PATH, 'tempo.txt'))
# Out:
# [47006, 72672, 165006, 77628, 216, 121350, 62066, 84880, 137600, 3238]

# %%
len(list_sentences)
# Out:
# 100000

# %%
list_sentences[0:10]
# Out:
# ['heran, sudah puluhan kali pemilihan pansus, baru kali ini berjalan alot dan sampai harus berjalan melalui voting.',
#  'masalah ini seperti upah buruh, aksi buruh, dan masalah-masalah keamanan lainnya.',
#  'pengadilan in absentia digelar karena hendra rahardja kini masih berada di australia dan menolak diekstradisi ke indonesia.',
#  'tapi harus diingat, konsepnya itu penanggulangan pertama dilakukan oleh pemda.',
#  'forum silaturahmi ulama yang beranggotakan para ulama di cisarua, bogor, jawa barat meminta aparat kepolisian untuk membebaskan santri-santrinya.',
#  'menurutnya, kekurangbijakan mpr dalam mengambil keputusan justru akan melahirkan sesuatu yang menyakitkan bagi bangsa ini.',
#  'meski demikian, menurut dia, tetap diperlukan surat resmi ke interpol.',
#  'jadi tak semuanya berindikasi komunis.',
#  'setelah itu presiden dan wapres melakukan acara foto bersama dengan para anggota kontingen yang dilanjutkan dengan acara ramah ramah di lingkungan wisma negara.',
#  'saya harus menghindari untuk menyatakan pasti adanya keterlibatan itu.']

# %%
for split in range(5):
  start_idx = split*20000
  stop_idx = start_idx + 20000
  with open(os.path.join(FOLDER_PATH, f'20k_indo4b_tempo_{split+1}.txt'), 'w') as f:
    for i in range(start_idx, stop_idx):
      f.write(list_sentences[i])
      f.write('\n')

# %% [markdown]
# ### Get 100k sentences from indo4b kompas (news article from Kompas)

# %%
list_sentences = get_sentences_from_corpus(os.path.join(FOLDER_PATH, 'kompas.txt'))
# Out:
# [7381, 86937, 72410, 27866, 32574, 33056, 10622, 95412, 42741, 11803]

# %%
len(list_sentences)
# Out:
# 100000

# %%
list_sentences[0:10]
# Out:
# ['di situ diceritakan bagaimana anaknya minta izin tidak bisa pulang lebaran, karena ada janji main ski di alpen, yang lain lagi masih magang di ibm di new york, dan seterusnya.',
#  'meski belum disampaikan, untuk sementara, pemerintah telah menetapkan angka defisit anggaran sebesar rp 56 trilyun lebih, atau 3,8 persen dari produk domestik bruto (pdb).',
#  'mendagri hari sabarno dalam tanggapannya mengenai berbagai minderheidsnota itu mengatakan bahwa pemerintah tidak pernah membuat peraturan yang mendiskriminasi perempuan dan laki-laki.',
#  'berbeda dalam penyelenggaraan komunikasi bergerak (selular), terdapat pilihan provider yang berkompetisi sehat memberikan pelayanan terbaiknya.',
#  'dalam arti tidak mengizinkan satu pesawat pun lepas landas.',
#  'untuk itu, tidak tanggung-tanggung, sembilan dari sepuluh orang amerika mendukung dilakukan tindakan militer.',
#  'utang piutang',
#  'kebijakan itu ditempuh untuk mengantisipasi ekspektasi masyarakat terhadap inflasi yang cukup tinggi dewasa ini.',
#  'harapannya, dia bisa memberikan bungkusan bom itu tanpa disadari orang yang diperintahkannya.',
#  'ditegaskan pula bahwa keputusan presiden yang inkonstitusional akan sangat berpengaruh terhadap pasar.']

# %%
for split in range(5):
  start_idx = split*20000
  stop_idx = start_idx + 20000
  with open(os.path.join(FOLDER_PATH, f'20k_indo4b_kompas_{split+1}.txt'), 'w') as f:
    for i in range(start_idx, stop_idx):
      f.write(list_sentences[i])
      f.write('\n')

# %%
# %cd /content/processed_uncased_blanklines
# Out:
# /content/processed_uncased_blanklines

# %%
# !zip -q 200k_sentences_indo4b.zip *_indo4b_kompas_*.txt *_indo4b_tempo_*.txt

# %% [markdown]
# ## Generate AMR
# - Generate AMR for all those 200k sentences
# - note: the usage for AMR parser is following this repo https://github.com/banditelol/amr_parser

# %% [markdown]
# ### Setup

# %%
# !git clone https://github.com/taufiqhusada/amr_parser.git
# %cd /content/amr_parser
# Out:
# Cloning into 'amr_parser'...
# remote: Enumerating objects: 2542, done.
# remote: Counting objects: 100% (2542/2542), done.
# remote: Compressing objects: 100% (2093/2093), done.
# remote: Total 2542 (delta 489), reused 2483 (delta 438), pack-reused 0
# Receiving objects: 100% (2542/2542), 3.76 MiB | 20.91 MiB/s, done.
# Resolving deltas: 100% (489/489), done.
# /content/amr_parser

# %%
# !pip install -r requirements.txt
# !pip install pandas --upgrade
# Out:
# Collecting absl-py==0.13.0
#   Downloading absl_py-0.13.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 9.8 MB/s
# Collecting anago==1.0.8
#   Downloading anago-1.0.8-py3-none-any.whl (22 kB)
# Collecting anyio==3.2.1
#   Downloading anyio-3.2.1-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.0 MB/s
# Collecting argon2-cffi==20.1.0
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 8.4 MB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (1.6.3)
# Collecting async-generator==1.10
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting attrs==21.2.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.8 MB/s
# Requirement already satisfied: Babel==2.9.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (2.9.1)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.2.0)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 41.2 MB/s
# Collecting bleach==3.3.0
#   Downloading bleach-3.3.0-py2.py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 38.5 MB/s
# Collecting blis==0.7.4
#   Downloading blis-0.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 37.0 MB/s
# Collecting boto3==1.17.106
#   Downloading boto3-1.17.106-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 71.3 MB/s
# Collecting botocore==1.20.106
#   Downloading botocore-1.20.106-py2.py3-none-any.whl (7.7 MB)
#      |████████████████████████████████| 7.7 MB 69.0 MB/s
# Requirement already satisfied: bs4==0.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (0.0.1)
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting catalogue==2.0.4
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 73.6 MB/s
# Collecting cffi==1.14.5
#   Downloading cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 65.1 MB/s
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 72.6 MB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 21)) (7.1.2)
# Collecting cloudpickle==1.2.2
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Collecting colorama==0.4.4
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting conllu==4.4
#   Downloading conllu-4.4-py2.py3-none-any.whl (15 kB)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting cymem==2.0.5
#   Downloading cymem-2.0.5-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# Collecting debugpy==1.3.0
#   Downloading debugpy-1.3.0-cp37-cp37m-manylinux2014_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 56.9 MB/s
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 29)) (4.4.2)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 30)) (0.7.1)
# Requirement already satisfied: docopt==0.6.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 31)) (0.6.2)
# Requirement already satisfied: editdistance==0.5.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 32)) (0.5.3)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 33)) (0.3)
# Collecting Flask==2.0.1
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.8 MB/s
# Collecting Flask-Cors==3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting flatbuffers==1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting ftfy==6.0.3
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 3.7 MB/s
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 38)) (0.4.0)
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 92.5 MB/s
# Collecting google-auth==1.32.1
#   Downloading google_auth-1.32.1-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 74.4 MB/s
# Collecting google-auth-oauthlib==0.4.4
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 42)) (0.2.0)
# Collecting graphviz==0.16
#   Downloading graphviz-0.16-py2.py3-none-any.whl (19 kB)
# Collecting grpcio==1.34.1
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 54.0 MB/s
# Requirement already satisfied: h5py==3.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 45)) (3.1.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 46)) (2.10)
# Collecting ipykernel==6.0.1
#   Downloading ipykernel-6.0.1-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 63.6 MB/s
# Collecting ipython==7.25.0
#   Downloading ipython-7.25.0-py3-none-any.whl (786 kB)
#      |████████████████████████████████| 786 kB 62.8 MB/s
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 49)) (0.2.0)
# Collecting itsdangerous==2.0.1
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting jedi==0.18.0
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 55.4 MB/s
# Collecting Jinja2==3.0.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 84.4 MB/s
# Collecting jmespath==0.10.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting joblib==1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 69.8 MB/s
# Collecting json5==0.9.6
#   Downloading json5-0.9.6-py2.py3-none-any.whl (18 kB)
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.1 MB/s
# Collecting jupyter-client==6.1.12
#   Downloading jupyter_client-6.1.12-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 81.0 MB/s
# Collecting jupyter-core==4.7.1
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.4 MB/s
# Collecting jupyter-server==1.9.0
#   Downloading jupyter_server-1.9.0-py3-none-any.whl (389 kB)
#      |████████████████████████████████| 389 kB 69.1 MB/s
# Collecting jupyterlab==3.0.16
#   Downloading jupyterlab-3.0.16-py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 18.4 MB/s
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 61)) (0.1.2)
# Collecting jupyterlab-server==2.6.0
#   Downloading jupyterlab_server-2.6.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.7 MB/s
# Collecting Keras==2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting keras-nightly==2.5.0.dev2021032900
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.2 MB/s
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 65)) (1.1.2)
# Collecting kiwisolver==1.3.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.9 MB/s
# Collecting lxml==4.6.3
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 56.4 MB/s
# Collecting Markdown==3.3.4
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 8.7 MB/s
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 69)) (2.0.1)
# Collecting matplotlib==3.4.2
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 54.4 MB/s
# Collecting matplotlib-inline==0.1.2
#   Downloading matplotlib_inline-0.1.2-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 72)) (0.8.4)
# Collecting murmurhash==1.0.5
#   Downloading murmurhash-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (20 kB)
# Collecting nbclassic==0.3.1
#   Downloading nbclassic-0.3.1-py3-none-any.whl (18 kB)
# Collecting nbclient==0.5.3
#   Downloading nbclient-0.5.3-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.2 MB/s
# Collecting nbconvert==6.1.0
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 64.3 MB/s
# Requirement already satisfied: nbformat==5.1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 77)) (5.1.3)
# Collecting nest-asyncio==1.5.1
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting networkx==2.5.1
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 61.7 MB/s
# Collecting nltk==3.6.2
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 58.8 MB/s
# Collecting notebook==6.4.0
#   Downloading notebook-6.4.0-py3-none-any.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 15.9 MB/s
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 82)) (1.19.5)
# Requirement already satisfied: oauthlib==3.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 83)) (3.1.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 84)) (3.3.0)
# Collecting overrides==3.1.0
#   Downloading overrides-3.1.0.tar.gz (11 kB)
# Collecting packaging==21.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.9 MB/s
# Collecting pandas==1.3.0
#   Downloading pandas-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 60.6 MB/s
# Collecting pandocfilters==1.4.3
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting parso==0.8.2
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.5 MB/s
# Collecting pathy==0.6.0
#   Downloading pathy-0.6.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.9 MB/s
# Collecting Penman==0.6.2
#   Downloading Penman-0.6.2-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 92)) (0.7.5)
# Collecting Pillow==8.3.1
#   Downloading Pillow-8.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 57.0 MB/s
# Collecting preshed==3.0.5
#   Downloading preshed-3.0.5-cp37-cp37m-manylinux2014_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 76.1 MB/s
# Collecting prometheus-client==0.11.0
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.9 MB/s
# Collecting prompt-toolkit==3.0.19
#   Downloading prompt_toolkit-3.0.19-py3-none-any.whl (368 kB)
#      |████████████████████████████████| 368 kB 68.7 MB/s
# Requirement already satisfied: protobuf==3.17.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 97)) (3.17.3)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 98)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 99)) (0.2.8)
# Collecting pycorenlp==0.3.0
#   Downloading pycorenlp-0.3.0.tar.gz (1.3 kB)
# Collecting pycparser==2.20
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 66.3 MB/s
# Collecting pydantic==1.7.4
#   Downloading pydantic-1.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 57.7 MB/s
# Collecting Pygments==2.9.0
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 61.3 MB/s
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.4 MB/s
# Requirement already satisfied: pyrsistent==0.18.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 105)) (0.18.0)
# Collecting python-crfsuite==0.9.7
#   Downloading python_crfsuite-0.9.7-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 59.8 MB/s
# Collecting python-dateutil==2.8.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 75.4 MB/s
# Collecting pytorch-pretrained-bert==0.6.2
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 84.0 MB/s
# Collecting pytz==2021.1
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 74.5 MB/s
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 51.4 MB/s
# Collecting pyzmq==22.1.0
#   Downloading pyzmq-22.1.0-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.5 MB/s
# Collecting regex==2021.7.6
#   Downloading regex-2021.7.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#      |████████████████████████████████| 722 kB 66.3 MB/s
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 9.6 MB/s
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 114)) (1.3.0)
# Collecting requests-unixsocket==0.2.0
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting rsa==4.7.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting s3transfer==0.4.2
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.0 MB/s
# Collecting Sastrawi==1.0.1
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 71.4 MB/s
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.4 MB/s
# Collecting scipy==1.7.0
#   Downloading scipy-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.3 MB/s
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 71.7 MB/s
# Collecting Send2Trash==1.7.1
#   Downloading Send2Trash-1.7.1-py3-none-any.whl (17 kB)
# Collecting seqeval==1.2.2
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.4 MB/s
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 124)) (1.15.0)
# Collecting smart-open==5.1.0
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.7 MB/s
# Collecting sniffio==1.2.0
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting soupsieve==2.2.1
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Collecting spacy==3.0.6
#   Downloading spacy-3.0.6-cp37-cp37m-manylinux2014_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 63.3 MB/s
# Collecting spacy-legacy==3.0.7
#   Downloading spacy_legacy-3.0.7-py2.py3-none-any.whl (13 kB)
# Collecting srsly==2.4.1
#   Downloading srsly-2.4.1-cp37-cp37m-manylinux2014_x86_64.whl (456 kB)
#      |████████████████████████████████| 456 kB 70.0 MB/s
# Collecting stanfordnlp==0.2.0
#   Downloading stanfordnlp-0.2.0-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 65.6 MB/s
# Collecting stanza==1.2.1
#   Downloading stanza-1.2.1-py3-none-any.whl (334 kB)
#      |████████████████████████████████| 334 kB 65.8 MB/s
# Requirement already satisfied: tabulate==0.8.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 133)) (0.8.9)
# Collecting tensorboard==2.5.0
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 55.2 MB/s
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 135)) (0.6.1)
# Collecting tensorboard-plugin-wit==1.8.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 64.2 MB/s
# Collecting tensorboardX==1.2
#   Downloading tensorboardX-1.2-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 3.8 MB/s
# Collecting tensorflow==2.5.0
#   Downloading tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 17 kB/s
# Collecting tensorflow-estimator==2.5.0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 74.8 MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 140)) (1.1.0)
# Collecting terminado==0.10.1
#   Downloading terminado-0.10.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: testpath==0.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 142)) (0.5.0)
# Collecting thinc==8.0.7
#   Downloading thinc-8.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (619 kB)
#      |████████████████████████████████| 619 kB 63.9 MB/s
# Collecting threadpoolctl==2.1.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting tornado==6.1
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 80.0 MB/s
# Collecting tqdm==4.61.2
#   Downloading tqdm-4.61.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 6.1 MB/s
# Collecting traitlets==5.0.5
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 12.4 MB/s
# Collecting typer==0.3.2
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting typing-extensions==3.7.4.3
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting typing-utils==0.1.0
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting urllib3==1.26.6
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 77.2 MB/s
# Collecting wasabi==0.8.2
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 154)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 155)) (0.5.1)
# Collecting websocket-client==1.1.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 8.5 MB/s
# Collecting Werkzeug==2.0.1
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 74.3 MB/s
# Collecting word2number==1.1
#   Downloading word2number-1.1.zip (9.7 kB)
# Collecting wordcloud==1.8.1
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
#      |████████████████████████████████| 366 kB 65.1 MB/s
# Collecting wrapt==1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting xgboost==1.2.0
#   Downloading xgboost-1.2.0-py3-none-manylinux2010_x86_64.whl (148.9 MB)
#      |████████████████████████████████| 148.9 MB 46 kB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse==1.6.3->-r requirements.txt (line 5)) (0.37.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue==2.0.4->-r requirements.txt (line 17)) (3.7.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth==1.32.1->-r requirements.txt (line 40)) (57.4.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py==3.1.0->-r requirements.txt (line 45)) (1.5.2)
# Collecting importlib-metadata<4
#   Downloading importlib_metadata-3.10.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython==7.25.0->-r requirements.txt (line 48)) (4.8.0)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert==0.6.2->-r requirements.txt (line 108)) (1.10.0+cu111)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado==0.10.1->-r requirements.txt (line 141)) (0.7.0)
# Building wheels for collected packages: ftfy, overrides, pandocfilters, pycorenlp, seqeval, word2number, wrapt
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=e469d21a253040451525767e23de82519825ee98d0441003d02b7b360b40577f
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10187 sha256=e257b55e7cd3a1502115acb9950bd643d46035d719bd8e93c02c4eeb2e14f978
#   Stored in directory: /root/.cache/pip/wheels/3a/0d/38/01a9bc6e20dcfaf0a6a7b552d03137558ba1c38aea47644682
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=8007 sha256=6df99ed95ce70536733998db4db14e6f50b4477ba23bb6c99c77bafe9303b0dc
#   Stored in directory: /root/.cache/pip/wheels/42/81/34/545dc2fbf0e9137811e901108d37fc04650e81d48f97078000
#   Building wheel for pycorenlp (setup.py) ... done
#   Created wheel for pycorenlp: filename=pycorenlp-0.3.0-py3-none-any.whl size=2145 sha256=85cff8db0f2c3dc4ffe62a7310c3a98f65e07cf8df611e388dfa87e70c6ebaf0
#   Stored in directory: /root/.cache/pip/wheels/83/d8/ad/6b2276343ac605ee47e6beddb28331e96377909e5c816539c3
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=418cc9d7095f9e632abb7e985b9eb5347d6e44247a542ee74d3ce821169ac4e1
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=197d2aeb40bbf6dd8585bb0d0a0d80486cb9fd94e2e0c761780173518db3c9d0
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68717 sha256=03d30a7ecfc685bf3e454ea521a4de609e97a1557d36e019a02323201b2ab59d
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built ftfy overrides pandocfilters pycorenlp seqeval word2number wrapt
# Installing collected packages: typing-extensions, traitlets, importlib-metadata, attrs, urllib3, tornado, pyzmq, python-dateutil, pyparsing, parso, jupyter-core, jsonschema, chardet, certifi, rsa, requests, Pygments, pycparser, prompt-toolkit, packaging, nest-asyncio, matplotlib-inline, jupyter-client, jedi, cachetools, async-generator, sniffio, pandocfilters, nbclient, jmespath, Jinja2, ipython, google-auth, debugpy, cffi, bleach, Werkzeug, websocket-client, threadpoolctl, terminado, tensorboard-plugin-wit, Send2Trash, scipy, requests-unixsocket, pytz, prometheus-client, nbconvert, murmurhash, Markdown, joblib, ipykernel, grpcio, google-auth-oauthlib, cymem, catalogue, botocore, argon2-cffi, anyio, absl-py, wrapt, wasabi, typer, tensorflow-estimator, tensorboard, srsly, soupsieve, smart-open, scikit-learn, s3transfer, PyYAML, pydantic, preshed, Pillow, notebook, kiwisolver, keras-nightly, jupyter-server, json5, itsdangerous, flatbuffers, cycler, blis, tqdm, thinc, tensorflow, spacy-legacy, seqeval, regex, pathy, pandas, nbclassic, matplotlib, Keras, jupyterlab-server, Flask, boto3, beautifulsoup4, xgboost, wordcloud, word2number, typing-utils, tensorboardX, stanza, stanfordnlp, spacy, seaborn, Sastrawi, pytorch-pretrained-bert, python-crfsuite, pycorenlp, Penman, overrides, nltk, networkx, lxml, jupyterlab, graphviz, gensim, ftfy, Flask-Cors, conllu, colorama, cloudpickle, anago
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.0
#     Uninstalling importlib-metadata-4.10.0:
#       Successfully uninstalled importlib-metadata-4.10.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 22.3.0
#     Uninstalling pyzmq-22.3.0:
#       Successfully uninstalled pyzmq-22.3.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.6
#     Uninstalling pyparsing-3.0.6:
#       Successfully uninstalled pyparsing-3.0.6
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.9.1
#     Uninstalling jupyter-core-4.9.1:
#       Successfully uninstalled jupyter-core-4.9.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.21
#     Uninstalling pycparser-2.21:
#       Successfully uninstalled pycparser-2.21
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.4
#     Uninstalling nest-asyncio-1.5.4:
#       Successfully uninstalled nest-asyncio-1.5.4
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.3
#     Uninstalling matplotlib-inline-0.1.3:
#       Successfully uninstalled matplotlib-inline-0.1.3
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.18.1
#     Uninstalling jedi-0.18.1:
#       Successfully uninstalled jedi-0.18.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Uninstalling cachetools-4.2.4:
#       Successfully uninstalled cachetools-4.2.4
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.5.0
#     Uninstalling pandocfilters-1.5.0:
#       Successfully uninstalled pandocfilters-1.5.0
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.5.9
#     Uninstalling nbclient-0.5.9:
#       Successfully uninstalled nbclient-0.5.9
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.0.0
#     Uninstalling debugpy-1.0.0:
#       Successfully uninstalled debugpy-1.0.0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.15.0
#     Uninstalling cffi-1.15.0:
#       Successfully uninstalled cffi-1.15.0
#   Attempting uninstall: bleach
#     Found existing installation: bleach 4.1.0
#     Uninstalling bleach-4.1.0:
#       Successfully uninstalled bleach-4.1.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.0.0
#     Uninstalling threadpoolctl-3.0.0:
#       Successfully uninstalled threadpoolctl-3.0.0
#   Attempting uninstall: terminado
#     Found existing installation: terminado 0.12.1
#     Uninstalling terminado-0.12.1:
#       Successfully uninstalled terminado-0.12.1
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.1
#     Uninstalling tensorboard-plugin-wit-1.8.1:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.1
#   Attempting uninstall: Send2Trash
#     Found existing installation: Send2Trash 1.8.0
#     Uninstalling Send2Trash-1.8.0:
#       Successfully uninstalled Send2Trash-1.8.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.12.0
#     Uninstalling prometheus-client-0.12.0:
#       Successfully uninstalled prometheus-client-0.12.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.6
#     Uninstalling murmurhash-1.0.6:
#       Successfully uninstalled murmurhash-1.0.6
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.3.6
#     Uninstalling Markdown-3.3.6:
#       Successfully uninstalled Markdown-3.3.6
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.6
#     Uninstalling cymem-2.0.6:
#       Successfully uninstalled cymem-2.0.6
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: argon2-cffi
#     Found existing installation: argon2-cffi 21.3.0
#     Uninstalling argon2-cffi-21.3.0:
#       Successfully uninstalled argon2-cffi-21.3.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 0.9.0
#     Uninstalling wasabi-0.9.0:
#       Successfully uninstalled wasabi-0.9.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.2.1
#     Uninstalling smart-open-5.2.1:
#       Successfully uninstalled smart-open-5.2.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.6
#     Uninstalling preshed-3.0.6:
#       Successfully uninstalled preshed-3.0.6
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.3.1
#     Uninstalling notebook-5.3.1:
#       Successfully uninstalled notebook-5.3.1
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.3.2
#     Uninstalling kiwisolver-1.3.2:
#       Successfully uninstalled kiwisolver-1.3.2
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: blis
#     Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: Keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.5.0
#     Uninstalling wordcloud-1.5.0:
#       Successfully uninstalled wordcloud-1.5.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.15.0 requires cloudpickle>=1.3, but you have cloudpickle 1.2.2 which is incompatible.
# tensorflow-metadata 1.5.0 requires absl-py<0.13,>=0.9, but you have absl-py 0.13.0 which is incompatible.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.19 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.0.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.25.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 6.4.0 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Flask-2.0.1 Flask-Cors-3.0.10 Jinja2-3.0.1 Keras-2.4.3 Markdown-3.3.4 Penman-0.6.2 Pillow-8.3.1 PyYAML-5.4.1 Pygments-2.9.0 Sastrawi-1.0.1 Send2Trash-1.7.1 Werkzeug-2.0.1 absl-py-0.13.0 anago-1.0.8 anyio-3.2.1 argon2-cffi-20.1.0 async-generator-1.10 attrs-21.2.0 beautifulsoup4-4.9.3 bleach-3.3.0 blis-0.7.4 boto3-1.17.106 botocore-1.20.106 cachetools-4.2.2 catalogue-2.0.4 certifi-2021.5.30 cffi-1.14.5 chardet-4.0.0 cloudpickle-1.2.2 colorama-0.4.4 conllu-4.4 cycler-0.10.0 cymem-2.0.5 debugpy-1.3.0 flatbuffers-1.12 ftfy-6.0.3 gensim-3.8.3 google-auth-1.32.1 google-auth-oauthlib-0.4.4 graphviz-0.16 grpcio-1.34.1 importlib-metadata-3.10.1 ipykernel-6.0.1 ipython-7.25.0 itsdangerous-2.0.1 jedi-0.18.0 jmespath-0.10.0 joblib-1.0.1 json5-0.9.6 jsonschema-3.2.0 jupyter-client-6.1.12 jupyter-core-4.7.1 jupyter-server-1.9.0 jupyterlab-3.0.16 jupyterlab-server-2.6.0 keras-nightly-2.5.0.dev2021032900 kiwisolver-1.3.1 lxml-4.6.3 matplotlib-3.4.2 matplotlib-inline-0.1.2 murmurhash-1.0.5 nbclassic-0.3.1 nbclient-0.5.3 nbconvert-6.1.0 nest-asyncio-1.5.1 networkx-2.5.1 nltk-3.6.2 notebook-6.4.0 overrides-3.1.0 packaging-21.0 pandas-1.3.0 pandocfilters-1.4.3 parso-0.8.2 pathy-0.6.0 preshed-3.0.5 prometheus-client-0.11.0 prompt-toolkit-3.0.19 pycorenlp-0.3.0 pycparser-2.20 pydantic-1.7.4 pyparsing-2.4.7 python-crfsuite-0.9.7 python-dateutil-2.8.1 pytorch-pretrained-bert-0.6.2 pytz-2021.1 pyzmq-22.1.0 regex-2021.7.6 requests-2.25.1 requests-unixsocket-0.2.0 rsa-4.7.2 s3transfer-0.4.2 scikit-learn-0.24.2 scipy-1.7.0 seaborn-0.9.0 seqeval-1.2.2 smart-open-5.1.0 sniffio-1.2.0 soupsieve-2.2.1 spacy-3.0.6 spacy-legacy-3.0.7 srsly-2.4.1 stanfordnlp-0.2.0 stanza-1.2.1 tensorboard-2.5.0 tensorboard-plugin-wit-1.8.0 tensorboardX-1.2 tensorflow-2.5.0 tensorflow-estimator-2.5.0 terminado-0.10.1 thinc-8.0.7 threadpoolctl-2.1.0 tornado-6.1 tqdm-4.61.2 traitlets-5.0.5 typer-0.3.2 typing-extensions-3.7.4.3 typing-utils-0.1.0 urllib3-1.26.6 wasabi-0.8.2 websocket-client-1.1.0 word2number-1.1 wordcloud-1.8.1 wrapt-1.12.1 xgboost-1.2.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 8.4 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.0
#     Uninstalling pandas-1.3.0:
#       Successfully uninstalled pandas-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.0.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.25.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 6.4.0 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# Successfully installed pandas-1.3.5

# %%
# %cd /content/amr_parser
# !chmod +x update-anago.sh
# !./update-anago.sh -d /usr/local/lib/python3.7/dist-packages/anago
# Out:
# /content/amr_parser
# commit_hash is unset, using default hash directory
# anago directory: '/usr/local/lib/python3.7/dist-packages/anago'
# commit hash: '9afccaa5bcc232676f9c2b59faa4c9531fb25190'
# check https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190 for included files
# updating callbacks.py
# 2022-01-19 01:00:29 URL:https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190/anago/callbacks.py [1257/1257] -> "/usr/local/lib/python3.7/dist-packages/anago/callbacks.py" [1]
# updating layers.py
# 2022-01-19 01:00:29 URL:https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190/anago/layers.py [25660/25660] -> "/usr/local/lib/python3.7/dist-packages/anago/layers.py" [1]
# updating models.py
# 2022-01-19 01:00:30 URL:https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190/anago/models.py [4931/4931] -> "/usr/local/lib/python3.7/dist-packages/anago/models.py" [1]
# updating preprocessing.py
# 2022-01-19 01:00:33 URL:https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190/anago/preprocessing.py [5757/5757] -> "/usr/local/lib/python3.7/dist-packages/anago/preprocessing.py" [1]
# updating utils.py
# 2022-01-19 01:00:33 URL:https://raw.githubusercontent.com/banditelol/anago/9afccaa5bcc232676f9c2b59faa4c9531fb25190/anago/utils.py [7450/7450] -> "/usr/local/lib/python3.7/dist-packages/anago/utils.py" [1]

# %%
#Install needed resources 
import stanfordnlp; import stanza; import nltk; 
stanza.download('id'); nltk.download('punkt')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.1.json:   0%|   …
# 2022-01-19 01:00:40 INFO: Downloading default packages for language: id (Indonesian)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.1/id/default.zip:   0%|          | 0.00/201M [00:00<?,…
# 2022-01-19 01:01:16 INFO: Finished downloading models and saved to /root/stanza_resources.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %cd /content/amr_parser
# Download Adylan's Pretrained model
# !wget https://storage.googleapis.com/riset_amr/adylan/pretrained_feature_models.zip -O pretrained.zip
# !unzip pretrained.zip
# !rm pretrained.zip

# Download NER model
# !wget https://storage.googleapis.com/riset_amr/pretrained_model/ner/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip
# !unzip model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip -d pretrained
# !rm model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip

# Download Encoder-Decoder Model
# !wget https://storage.googleapis.com/riset_amr/adylan/pretrained_model_and_encoder.zip -O saved_model.zip 
# !unzip saved_model.zip -d saved_model 
# !rm saved_model.zip
# Out:
# /content/amr_parser
# --2022-01-19 01:01:16--  https://storage.googleapis.com/riset_amr/adylan/pretrained_feature_models.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 74.125.199.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180433604 (172M) [application/zip]
# Saving to: ‘pretrained.zip’
#
# pretrained.zip      100%[===================>] 172.07M  38.9MB/s    in 4.4s
#
# 2022-01-19 01:01:23 (38.9 MB/s) - ‘pretrained.zip’ saved [180433604/180433604]
#
# Archive:  pretrained.zip
#    creating: pretrained/
#    creating: pretrained/ner_tagger/
#   inflating: pretrained/ner_tagger/nerparams.json
#   inflating: pretrained/ner_tagger/nerprepro.pkl
#   inflating: pretrained/ner_tagger/nerweight.h5
#    creating: pretrained/pos_tagger/
#   inflating: pretrained/pos_tagger/all_indo_man_tag_corpus_model.crf.tagger
#    creating: pretrained/word2vec/
#    creating: pretrained/word2vec/id/
#   inflating: pretrained/word2vec/id/id.tsv
#   inflating: pretrained/word2vec/id/id.bin.gz
#    creating: pretrained/word2vec/id/.ipynb_checkpoints/
#   inflating: pretrained/word2vec/id/.ipynb_checkpoints/id-checkpoint.tsv
# --2022-01-19 01:01:26--  https://storage.googleapis.com/riset_amr/pretrained_model/ner/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 74.125.197.128, 74.125.142.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27040559 (26M) [application/zip]
# Saving to: ‘model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip’
#
# model_ner_12514_sof 100%[===================>]  25.79M  18.7MB/s    in 1.4s
#
# 2022-01-19 01:01:29 (18.7 MB/s) - ‘model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip’ saved [27040559/27040559]
#
# Archive:  model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV-20210926T165506Z-001.zip
#   inflating: pretrained/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV/saved_model.pb
#   inflating: pretrained/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV/keras_metadata.pb
#   inflating: pretrained/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV/dict.pickle
#   inflating: pretrained/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV/variables/variables.index
#   inflating: pretrained/model_ner_12514_softmax_v5_w2v_100_POS_LSTM_EmbNotTrainable_OOV/variables/variables.data-00000-of-00001
# --2022-01-19 01:01:30--  https://storage.googleapis.com/riset_amr/adylan/pretrained_model_and_encoder.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 74.125.197.128, 74.125.142.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 516142 (504K) [application/zip]
# Saving to: ‘saved_model.zip’
#
# saved_model.zip     100%[===================>] 504.04K  --.-KB/s    in 0.004s
#
# 2022-01-19 01:01:30 (130 MB/s) - ‘saved_model.zip’ saved [516142/516142]
#
# Archive:  saved_model.zip
#    creating: saved_model/encoder/
#   inflating: saved_model/encoder/label_encoder.pickle.dat
#   inflating: saved_model/encoder/one_hot_encoder.pickle.dat
#   inflating: saved_model/best_model_pretrained.pickle.dat

# %%
# %cd /content/amr_parser
# Out:
# /content/amr_parser

# %%
# !python amr_parser.py --predict --file /content/processed_uncased_blanklines/20k_indo4b_kompas_1.txt --output /content/AMR_20k_indo4b_kompas_1.txt

# %%
# !python amr_parser.py --predict --file /content/processed_uncased_blanklines/20k_indo4b_kompas_2.txt --output /content/AMR_20k_indo4b_kompas_2.txt

# %%
# !python amr_parser.py --predict --file /content/processed_uncased_blanklines/20k_indo4b_kompas_5.txt --output /content/AMR_20k_indo4b_kompas_5.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# le pen menilai kritik zidane itu tidak akan berpengaruh terhadap peluangnya mengalahkan presiden jacques chirac dalam pemilihan presiden babak kedua hari minggu.
#
# [Triple(source='vv1', relation='instance', target='bicara'), Triple(source='vv2', relation='instance', target='sedang'), Triple(source='vv3', relation='instance', target='juru'), Triple(source='vv4', relation='instance', target='fraksi'), Triple(source='vv5', relation='instance', target='satu'), Triple(source='vv6', relation='instance', target='bangsa'), Triple(source='vv7', relation='instance', target='dan'), Triple(source='vv8', relation='instance', target='indonesia'), Triple(source='vv9', relation='instance', target='kata'), Triple(source='vv10', relation='instance', target='fkki'), Triple(source='vv11', relation='instance', target='sutradara'), Triple(source='vv12', relation='instance', target='gintings'), Triple(source='vv13', relation='instance', target='paham'), Triple(source='vv14', relation='instance', target='bisa'), Triple(source='vv15', relation='instance', target='hasil'), Triple(source='vv16', relation='instance', target='lidi'), Triple(source='vv17', relation='instance', target='pansus'), Triple(source='vv18', relation='instance', target='pandang'), Triple(source='vv19', relation='instance', target='laku'), Triple(source='vv20', relation='instance', target='perlu'), Triple(source='vv21', relation='instance', target='lanjut'), Triple(source='vv22', relation='instance', target='tidak'), Triple(source='vv23', relation='instance', target='tuntas'), Triple(source='vv24', relation='instance', target='kasus'), Triple(source='vv25', relation='instance', target='dapat'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='ARG0', target='vv3'), Triple(source='vv1', relation='ARG1', target='vv4'), Triple(source='vv9', relation='ARG1', target='vv5'), Triple(source='vv4', relation='mod', target='vv6'), Triple(source='vv5', relation='mod', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv18', relation='mod', target='vv9'), Triple(source='vv6', relation='mod', target='vv10'), Triple(source='vv1', relation='mod', target='vv11'), Triple(source='vv9', relation='mod', target='vv12'), Triple(source='vv9', relation='ARG0', target='vv13'), Triple(source='vv11', relation='mod', target='vv14'), Triple(source='vv9', relation='mod', target='vv15'), Triple(source='vv13', relation='mod', target='vv16'), Triple(source='vv13', relation='ARG1', target='vv17'), Triple(source='vv15', relation='mod', target='vv18'), Triple(source='vv16', relation='mod', target='vv19'), Triple(source='vv13', relation='mod', target='vv20'), Triple(source='vv18', relation='ARG1', target='vv21'), Triple(source='vv19', relation='mod', target='vv22'), Triple(source='vv19', relation='mod', target='vv23'), Triple(source='vv21', relation='mod', target='vv24'), Triple(source='vv19', relation='mod', target='vv25'), Triple(source='vv23', relation='ARG1', target='vv26'), Triple(source='vv23', relation='mod', target='vv27')]
# sedangkan juru bicara fraksi kesatuan dan kebangsaan indonesia (f-kki), sutradara gintings, mengatakan, fraksinya bisa memahami hasil penyelidikan pansus dan memandang perlu dilakukan tidak lanjut agar kasus ini dapat dituntaskan.
#
# [Triple(source='vv1', relation='instance', target='terobos'), Triple(source='vv2', relation='instance', target='dia'), Triple(source='vv3', relation='instance', target='anggota'), Triple(source='vv4', relation='instance', target='dpr'), Triple(source='vv5', relation='instance', target='kena'), Triple(source='vv6', relation='instance', target='lampu'), Triple(source='vv7', relation='instance', target='merah'), Triple(source='vv8', relation='instance', target='sudah'), Triple(source='vv9', relation='instance', target='masih'), Triple(source='vv10', relation='instance', target='juga'), Triple(source='vv1', relation='ARG1', target='vv2'), Triple(source='vv1', relation='ARG1', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv5', relation='ARG1', target='vv5'), Triple(source='vv6', relation='mod', target='vv6'), Triple(source='vv7', relation='mod', target='vv7'), Triple(source='vv1', relation='mod', target='vv8'), Triple(source='vv1', relation='mod', target='vv9')]
# sebab kalau dia anggota dpr, kena lampu sudah merah masih diterobos juga.
#
# [Triple(source='vv1', relation='instance', target='sementara'), Triple(source='vv2', relation='instance', target='itu'), Triple(source='vv3', relation='instance', target='pamen'), Triple(source='vv4', relation='instance', target='delap'), Triple(source='vv5', relation='instance', target='sambut'), Triple(source='vv6', relation='instance', target='polri'), Triple(source='vv7', relation='instance', target='keluar'), Triple(source='vv8', relation='instance', target='saat'), Triple(source='vv9', relation='instance', target='ruang'), Triple(source='vv10', relation='instance', target='yuda'), Triple(source='vv11', relation='instance', target='mabes'), Triple(source='vv12', relation='instance', target='langsung'), Triple(source='vv13', relation='instance', target='sanak'), Triple(source='vv14', relation='instance', target='keluarga'), Triple(source='vv15', relation='instance', target='anak'), Triple(source='vv16', relation='instance', target='istri'), Triple(source='vv17', relation='instance', target='dan'), Triple(source='vv1', relation='mod', target='vv1'), Triple(source='vv5', relation='ARG1', target='vv2'), Triple(source='vv3', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv5'), Triple(source='vv11', relation='mod', target='vv6'), Triple(source='vv3', relation='mod', target='vv7'), Triple(source='vv7', relation='mod', target='vv8'), Triple(source='vv7', relation='ARG1', target='vv9'), Triple(source='vv9', relation='mod', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv5', relation='mod', target='vv12'), Triple(source='vv5', relation='ARG1', target='vv13'), Triple(source='vv13', relation='mod', target='vv14'), Triple(source='vv14', relation='mod', target='vv15'), Triple(source='vv13', relation='mod', target='vv16'), Triple(source='vv16', relation='mod', target='vv17')]
# sementara itu kedelapan pamen polri tersebut saat keluar dari ruang yuda mabes polri, langsung disambut oleh sanak keluarga, anak dan istri mereka.
#
# [Triple(source='vv1', relation='instance', target='peka'), Triple(source='vv2', relation='instance', target='presiden'), Triple(source='vv3', relation='instance', target='abdurrahman'), Triple(source='vv4', relation='instance', target='wahid'), Triple(source='vv5', relation='instance', target='baik'), Triple(source='vv6', relation='instance', target='ubah'), Triple(source='vv7', relation='instance', target='sikap'), Triple(source='vv8', relation='instance', target='wapres'), Triple(source='vv9', relation='instance', target='megawati'), Triple(source='vv10', relation='instance', target='beda'), Triple(source='vv11', relation='instance', target='sangat'), Triple(source='vv12', relation='instance', target='waktu'), Triple(source='vv13', relation='instance', target='lalu'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv1', relation='mod', target='vv5'), Triple(source='vv1', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv10', relation='mod', target='vv8'), Triple(source='vv7', relation='mod', target='vv9'), Triple(source='vv8', relation='mod', target='vv10'), Triple(source='vv7', relation='mod', target='vv11'), Triple(source='vv10', relation='mod', target='vv12'), Triple(source='vv7', relation='mod', target='vv13'), Triple(source='vv12', relation='mod', target='vv14')]
# presiden abdurrahman wahid sebaiknya peka dengan perubahan sikap wapres megawati ini yang sangat berbeda dengan sikapnya beberapa waktu lalu.
#
# [Triple(source='vv1', relation='instance', target='kembang'), Triple(source='vv2', relation='instance', target='giat'), Triple(source='vv3', relation='instance', target='awal'), Triple(source='vv4', relation='instance', target='jadi'), Triple(source='vv5', relation='instance', target='hitung'), Triple(source='vv6', relation='instance', target='deret'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv1', relation='ARG1', target='vv4'), Triple(source='vv4', relation='ARG1', target='vv5'), Triple(source='vv6', relation='mod', target='vv6'), Triple(source='vv5', relation='mod', target='vv7')]
# kegiatan awal ini berkembang menjadi hitungan deret hitung.
#
# [Triple(source='vv1', relation='instance', target='turut'), Triple(source='vv2', relation='instance', target='masih'), Triple(source='vv3', relation='instance', target='vecernje'), Triple(source='vv4', relation='instance', target='novosti'), Triple(source='vv5', relation='instance', target='marija'), Triple(source='vv6', relation='instance', target='rencana'), Triple(source='vv7', relation='instance', target='tinggal'), Triple(source='vv8', relation='instance', target='akan'), Triple(source='vv9', relation='instance', target='montenegro'), Triple(source='vv10', relation='instance', target='waktu'), Triple(source='vv11', relation='instance', target='lama'), Triple(source='vv12', relation='instance', target='bahkan'), Triple(source='vv13', relation='instance', target='atau'), Triple(source='vv1', relation='mod', target='vv1'), Triple(source='vv1', relation='ARG1', target='vv2'), Triple(source='vv3', relation='mod', target='vv3'), Triple(source='vv4', relation='mod', target='vv4'), Triple(source='vv5', relation='mod', target='vv5'), Triple(source='vv7', relation='mod', target='vv7'), Triple(source='vv7', relation='ARG1', target='vv8'), Triple(source='vv7', relation='ARG1', target='vv9'), Triple(source='vv10', relation='mod', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv10', relation='mod', target='vv12'), Triple(source='vv12', relation='mod', target='vv13')]
# masih menurut  vecernje novosti , marija berencana akan tinggal di montenegro untuk waktu yang lama, atau bahkan untuk selamanya.
#
# [Triple(source='vv1', relation='instance', target='ingat'), Triple(source='vv2', relation='instance', target='demikian'), Triple(source='vv3', relation='instance', target='ekonom'), Triple(source='vv4', relation='instance', target='senior'), Triple(source='vv5', relation='instance', target='m'), Triple(source='vv6', relation='instance', target='sadli'), Triple(source='vv7', relation='instance', target='kamis'), Triple(source='vv8', relation='instance', target='146'), Triple(source='vv9', relation='instance', target='tanggap'), Triple(source='vv10', relation='instance', target='tentang'), Triple(source='vv11', relation='instance', target='adu'), Triple(source='vv12', relation='instance', target='kuat'), Triple(source='vv13', relation='instance', target='buruh'), Triple(source='vv14', relation='instance', target='usaha'), Triple(source='vv15', relation='instance', target='dan'), Triple(source='vv16', relation='instance', target='sangkut'), Triple(source='vv17', relation='instance', target='atur'), Triple(source='vv18', relation='instance', target='sangon'), Triple(source='vv19', relation='instance', target='hakhak'), Triple(source='vv20', relation='instance', target='lain'), Triple(source='vv21', relation='instance', target='soal'), Triple(source='vv22', relation='instance', target='kepmennakertrans'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='ARG1', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv3', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv6', relation='time', target='vv7'), Triple(source='vv7', relation='mod', target='vv8'), Triple(source='vv1', relation='mod', target='vv9'), Triple(source='vv9', relation='ARG1', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv11', relation='mod', target='vv12'), Triple(source='vv10', relation='mod', target='vv13'), Triple(source='vv19', relation='mod', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv14', relation='mod', target='vv16'), Triple(source='vv19', relation='mod', target='vv17'), Triple(source='vv9', relation='mod', target='vv18'), Triple(source='vv16', relation='ARG0', target='vv19'), Triple(source='vv17', relation='mod', target='vv20'), Triple(source='vv18', relation='mod', target='vv21'), Triple(source='vv13', relation='mod', target='vv22'), Triple(source='vv18', relation='mod', target='vv23'), Triple(source='vv21', relation='location', target='vv24')]
# demikian diingatkan oleh ekonom senior m sadli, kamis (14/6), menanggapi pertentangan adu kuat antara buruh dan pengusaha menyangkut aturan mengenai pesangon dan hak-hak buruh lainnya yang dipersoalkan dalam kepmennakertrans tersebut.
#
# [Triple(source='vv1', relation='instance', target='kirim'), Triple(source='vv2', relation='instance', target='tt'), Triple(source='vv3', relation='instance', target='pmp3bbm'), Triple(source='vv4', relation='instance', target='telah'), Triple(source='vv5', relation='instance', target='surat'), Triple(source='vv6', relation='instance', target='dirut'), Triple(source='vv7', relation='instance', target='pertamina'), Triple(source='vv8', relation='instance', target='tindak'), Triple(source='vv9', relation='instance', target='oknum'), Triple(source='vv10', relation='instance', target='lalu'), Triple(source='vv11', relation='instance', target='nomor'), Triple(source='vv12', relation='instance', target='145'), Triple(source='vv13', relation='instance', target='tg'), Triple(source='vv14', relation='instance', target='sbv2001'), Triple(source='vv15', relation='instance', target='tanggal'), Triple(source='vv16', relation='instance', target='mei'), Triple(source='vv17', relation='instance', target='10'), Triple(source='vv18', relation='instance', target='2001'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv1', relation='mod', target='vv4'), Triple(source='vv1', relation='ARG1', target='vv5'), Triple(source='vv8', relation='location', target='vv6'), Triple(source='vv5', relation='mod', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv1', relation='mod', target='vv9'), Triple(source='vv8', relation='ARG1', target='vv10'), Triple(source='vv5', relation='mod', target='vv11'), Triple(source='vv5', relation='mod', target='vv12'), Triple(source='vv11', relation='mod', target='vv13'), Triple(source='vv11', relation='mod', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv5', relation='mod', target='vv16'), Triple(source='vv15', relation='mod', target='vv17'), Triple(source='vv16', relation='mod', target='vv18'), Triple(source='vv16', relation='mod', target='vv19')]
# tt pmp3-bbm telah mengirim surat kepada dirut pertamina agar menindak oknum tersebut, melalui surat nomor 145/ tg/ sb/v/2001 tertanggal 10 mei 2001.
#
# [Triple(source='vv1', relation='instance', target='harap'), Triple(source='vv2', relation='instance', target='demikian'), Triple(source='vv3', relation='instance', target='ada'), Triple(source='vv4', relation='instance', target='tidak'), Triple(source='vv5', relation='instance', target='kesan'), Triple(source='vv6', relation='instance', target='pemerintah'), Triple(source='vv7', relation='instance', target='pilih'), Triple(source='vv8', relation='instance', target='nanti'), Triple(source='vv9', relation='instance', target='adalah'), Triple(source='vv10', relation='instance', target='orde'), Triple(source='vv11', relation='instance', target='baru'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv3', relation='ARG1', target='vv5'), Triple(source='vv6', relation='ARG0', target='vv6'), Triple(source='vv3', relation='ARG1', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv7', relation='ARG1', target='vv9'), Triple(source='vv6', relation='mod', target='vv10'), Triple(source='vv6', relation='mod', target='vv11'), Triple(source='vv10', relation='mod', target='vv12')]
# dengan demikian diharapkan tidak ada kesan bahwa pemerintah yang terpilih nanti itu adalah pemerintah orde baru.
#
# [Triple(source='vv1', relation='instance', target='misal'), Triple(source='vv2', relation='instance', target='mia'), Triple(source='vv3', relation='instance', target='aku'), Triple(source='vv4', relation='instance', target='asal'), Triple(source='vv5', relation='instance', target='indramayu'), Triple(source='vv6', relation='instance', target='nisa'), Triple(source='vv7', relation='instance', target='atau'), Triple(source='vv8', relation='instance', target='asli'), Triple(source='vv9', relation='instance', target='subang'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv6', relation='mod', target='vv4'), Triple(source='vv3', relation='mod', target='vv5'), Triple(source='vv4', relation='location', target='vv6'), Triple(source='vv5', relation='mod', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv3', relation='mod', target='vv9'), Triple(source='vv3', relation='ARG1', target='vv10')]
# misalnya, mia yang mengaku berasal dari indramayu atau nisa yang mengaku asli subang.
#
# [Triple(source='vv1', relation='instance', target='ajak'), Triple(source='vv2', relation='instance', target='sambut'), Triple(source='vv3', relation='instance', target='presiden'), Triple(source='vv4', relation='instance', target='abdurrahman'), Triple(source='vv5', relation='instance', target='wahid'), Triple(source='vv6', relation='instance', target='bangsa'), Triple(source='vv7', relation='instance', target='indonesia'), Triple(source='vv8', relation='instance', target='lanjut'), Triple(source='vv9', relation='instance', target='karyakarya'), Triple(source='vv10', relation='instance', target='almarhum'), Triple(source='vv11', relation='instance', target='beri'), Triple(source='vv12', relation='instance', target='telah'), Triple(source='vv13', relation='instance', target='hal'), Triple(source='vv14', relation='instance', target='baik'), Triple(source='vv15', relation='instance', target='negara'), Triple(source='vv16', relation='instance', target='dan'), Triple(source='vv17', relation='instance', target='khusus'), Triple(source='vv18', relation='instance', target='letak'), Triple(source='vv19', relation='instance', target='dasar'), Triple(source='vv20', relation='instance', target='kokoh'), Triple(source='vv21', relation='instance', target='tega'), Triple(source='vv22', relation='instance', target='hukum'), Triple(source='vv1', relation='ARG1', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv1', relation='ARG1', target='vv6'), Triple(source='vv13', relation='mod', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv1', relation='ARG1', target='vv9'), Triple(source='vv8', relation='ARG1', target='vv10'), Triple(source='vv9', relation='mod', target='vv11'), Triple(source='vv9', relation='mod', target='vv12'), Triple(source='vv11', relation='mod', target='vv13'), Triple(source='vv11', relation='ARG1', target='vv14'), Triple(source='vv15', relation='mod', target='vv15'), Triple(source='vv13', relation='mod', target='vv16'), Triple(source='vv6', relation='mod', target='vv17'), Triple(source='vv20', relation='ARG1', target='vv18'), Triple(source='vv15', relation='mod', target='vv19'), Triple(source='vv15', relation='mod', target='vv20'), Triple(source='vv11', relation='ARG1', target='vv21'), Triple(source='vv18', relation='ARG1', target='vv22'), Triple(source='vv19', relation='mod', target='vv23'), Triple(source='vv13', relation='mod', target='vv24'), Triple(source='vv21', relation='mod', target='vv25')]
# dalam sambutannya, presiden abdurrahman wahid mengajak bangsa indonesia untuk melanjutkan karya-karya almarhum yang telah memberikan hal terbaik kepada bangsa dan negara, khususnya dengan meletakkan dasar yang kokoh bagi negara dalam hal penegakan hukum.
#
# [Triple(source='vv1', relation='instance', target='jadi'), Triple(source='vv2', relation='instance', target='itu'), Triple(source='vv3', relation='instance', target='salur'), Triple(source='vv4', relation='instance', target='sopir'), Triple(source='vv5', relation='instance', target='truk'), Triple(source='vv6', relation='instance', target='tangki'), Triple(source='vv7', relation='instance', target='lokasi'), Triple(source='vv8', relation='instance', target='agen'), Triple(source='vv9', relation='instance', target='wilayah'), Triple(source='vv10', relation='instance', target='dki'), Triple(source='vv11', relation='instance', target='jakarta'), Triple(source='vv12', relation='instance', target='tidak'), Triple(source='vv13', relation='instance', target='bisa'), Triple(source='vv14', relation='instance', target='minyak'), Triple(source='vv15', relation='instance', target='tanah'), Triple(source='vv16', relation='instance', target='depok'), Triple(source='vv17', relation='instance', target='bogor'), Triple(source='vv18', relation='instance', target='tangerang'), Triple(source='vv19', relation='instance', target='bekasi'), Triple(source='vv20', relation='instance', target='atau'), Triple(source='vv21', relation='instance', target='lain'), Triple(source='vv22', relation='instance', target='luar'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv3', relation='ARG0', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv4', relation='mod', target='vv7'), Triple(source='vv7', relation='ARG0', target='vv8'), Triple(source='vv7', relation='location', target='vv9'), Triple(source='vv14', relation='mod', target='vv10'), Triple(source='vv16', relation='mod', target='vv11'), Triple(source='vv9', relation='mod', target='vv12'), Triple(source='vv10', relation='mod', target='vv13'), Triple(source='vv22', relation='mod', target='vv14'), Triple(source='vv3', relation='mod', target='vv15'), Triple(source='vv3', relation='mod', target='vv16'), Triple(source='vv3', relation='ARG1', target='vv17'), Triple(source='vv14', relation='mod', target='vv18'), Triple(source='vv9', relation='mod', target='vv19'), Triple(source='vv16', relation='mod', target='vv20'), Triple(source='vv17', relation='mod', target='vv21'), Triple(source='vv18', relation='mod', target='vv22'), Triple(source='vv9', relation='mod', target='vv23'), Triple(source='vv9', relation='mod', target='vv24'), Triple(source='vv9', relation='mod', target='vv25')]
# itu terjadi karena sopir truk tangki yang agennya berlokasi di wilayah dki jakarta tidak bisa menyalurkan minyak tanah untuk wilayah depok, bogor, tangerang, bekasi, atau wilayah lainnya di luar jakarta.
#
# [Triple(source='vv1', relation='instance', target='tegas'), Triple(source='vv2', relation='instance', target='siswono'), Triple(source='vv3', relation='instance', target='juga'), Triple(source='vv4', relation='instance', target='usaha'), Triple(source='vv5', relation='instance', target='nasional'), Triple(source='vv6', relation='instance', target='investasi'), Triple(source='vv7', relation='instance', target='ingin'), Triple(source='vv8', relation='instance', target='jalan'), Triple(source='vv9', relation='instance', target='tol'), Triple(source='vv10', relation='instance', target='tarik'), Triple(source='vv11', relation='instance', target='tidak'), Triple(source='vv12', relation='instance', target='akan'), Triple(source='vv13', relation='instance', target='lagi'), Triple(source='vv14', relation='instance', target='ada'), Triple(source='vv15', relation='instance', target='insentif'), Triple(source='vv16', relation='instance', target='bangun'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv1', relation='ARG1', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv4', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv6', relation='location', target='vv8'), Triple(source='vv16', relation='mod', target='vv9'), Triple(source='vv8', relation='mod', target='vv10'), Triple(source='vv8', relation='mod', target='vv11'), Triple(source='vv1', relation='mod', target='vv12'), Triple(source='vv10', relation='mod', target='vv13'), Triple(source='vv14', relation='mod', target='vv14'), Triple(source='vv10', relation='mod', target='vv15'), Triple(source='vv10', relation='mod', target='vv16'), Triple(source='vv10', relation='mod', target='vv17'), Triple(source='vv14', relation='ARG1', target='vv18'), Triple(source='vv14', relation='ARG1', target='vv19')]
# siswono juga menegaskan, pengusaha nasional yang ingin berinvestasi di jalan tol tidak akan tertarik lagi bila tidak ada insentif dalam pembangunan jalan tol.
#
# [Triple(source='vv1', relation='instance', target='hasil'), Triple(source='vv2', relation='instance', target='hal'), Triple(source='vv3', relation='instance', target='akan'), Triple(source='vv4', relation='instance', target='bingung'), Triple(source='vv5', relation='instance', target='kultur'), Triple(source='vv6', relation='instance', target='mana'), Triple(source='vv7', relation='instance', target='pakai'), Triple(source='vv8', relation='instance', target='prosedur'), Triple(source='vv9', relation='instance', target='standar'), Triple(source='vv10', relation='instance', target='operasi'), Triple(source='vv11', relation='instance', target='siapa'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv7', relation='mod', target='vv4'), Triple(source='vv7', relation='mod', target='vv5'), Triple(source='vv1', relation='ARG1', target='vv6'), Triple(source='vv4', relation='mod', target='vv7'), Triple(source='vv4', relation='mod', target='vv8'), Triple(source='vv4', relation='mod', target='vv9'), Triple(source='vv11', relation='mod', target='vv10'), Triple(source='vv7', relation='ARG1', target='vv11'), Triple(source='vv8', relation='mod', target='vv12'), Triple(source='vv8', relation='mod', target='vv13'), Triple(source='vv8', relation='mod', target='vv14')]
# hal itu akan menghasilkan kebingungan, kultur mana yang akan dipakai, standar prosedur operasi siapa yang akan dipakai.
#
# [Triple(source='vv1', relation='instance', target='tuntut'), Triple(source='vv2', relation='instance', target='massa'), Triple(source='vv3', relation='instance', target='laku'), Triple(source='vv4', relation='instance', target='dialog'), Triple(source='vv5', relation='instance', target='wakil'), Triple(source='vv6', relation='instance', target='partai'), Triple(source='vv7', relation='instance', target='ada'), Triple(source='vv8', relation='instance', target='dprd'), Triple(source='vv9', relation='instance', target='jatim'), Triple(source='vv10', relation='instance', target='utama'), Triple(source='vv11', relation='instance', target='amanat'), Triple(source='vv12', relation='instance', target='nasional'), Triple(source='vv13', relation='instance', target='pbb'), Triple(source='vv14', relation='instance', target='golkar'), Triple(source='vv15', relation='instance', target='dan'), Triple(source='vv16', relation='instance', target='satu'), Triple(source='vv17', relation='instance', target='bangun'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv1', relation='ARG1', target='vv3'), Triple(source='vv3', relation='ARG1', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv7', relation='ARG1', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv5', relation='mod', target='vv9'), Triple(source='vv7', relation='location', target='vv10'), Triple(source='vv8', relation='mod', target='vv11'), Triple(source='vv6', relation='mod', target='vv12'), Triple(source='vv6', relation='mod', target='vv13'), Triple(source='vv11', relation='mod', target='vv14'), Triple(source='vv11', relation='mod', target='vv15'), Triple(source='vv13', relation='mod', target='vv16'), Triple(source='vv6', relation='mod', target='vv17'), Triple(source='vv6', relation='mod', target='vv18'), Triple(source='vv16', relation='mod', target='vv19')]
# sebelumnya, massa menuntut agar dilakukan dialog dengan seluruh wakil partai yang ada di dprd jatim, terutama dengan partai amanat nasional, pbb, golkar, dan partai persatuan pembangunan.
#
# [Triple(source='vv1', relation='instance', target='catat'), Triple(source='vv2', relation='instance', target='umum'), Triple(source='vv3', relation='instance', target='harta'), Triple(source='vv4', relation='instance', target='selenggara'), Triple(source='vv5', relation='instance', target='negara'), Triple(source='vv6', relation='instance', target='ke14'), Triple(source='vv7', relation='instance', target='markus'), Triple(source='vv8', relation='instance', target='parmadi'), Triple(source='vv9', relation='instance', target='komisaris'), Triple(source='vv10', relation='instance', target='pt'), Triple(source='vv11', relation='instance', target='bank'), Triple(source='vv12', relation='instance', target='mandiri'), Triple(source='vv13', relation='instance', target='tempat'), Triple(source='vv14', relation='instance', target='langsung'), Triple(source='vv15', relation='instance', target='posisi'), Triple(source='vv16', relation='instance', target='12'), Triple(source='vv17', relation='instance', target='besar'), Triple(source='vv18', relation='instance', target='kaya'), Triple(source='vv19', relation='instance', target='bawah'), Triple(source='vv20', relation='instance', target='akbar'), Triple(source='vv21', relation='instance', target='tandjung'), Triple(source='vv1', relation='location', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv1', relation='ARG1', target='vv4'), Triple(source='vv3', relation='mod', target='vv5'), Triple(source='vv15', relation='mod', target='vv6'), Triple(source='vv4', relation='mod', target='vv7'), Triple(source='vv4', relation='mod', target='vv8'), Triple(source='vv5', relation='mod', target='vv9'), Triple(source='vv3', relation='mod', target='vv10'), Triple(source='vv7', relation='mod', target='vv11'), Triple(source='vv8', relation='mod', target='vv12'), Triple(source='vv9', relation='mod', target='vv13'), Triple(source='vv10', relation='mod', target='vv14'), Triple(source='vv11', relation='mod', target='vv15'), Triple(source='vv3', relation='mod', target='vv16'), Triple(source='vv13', relation='mod', target='vv17'), Triple(source='vv13', relation='ARG1', target='vv18'), Triple(source='vv19', relation='mod', target='vv19'), Triple(source='vv4', relation='mod', target='vv20'), Triple(source='vv15', relation='mod', target='vv21'), Triple(source='vv5', relation='mod', target='vv22'), Triple(source='vv15', relation='mod', target='vv23'), Triple(source='vv15', relation='mod', target='vv24'), Triple(source='vv20', relation='mod', target='vv25')]
# pada pengumuman harta penyelenggara negara ke-14, tercatat harta markus parmadi, komisaris pt bank mandiri yang langsung menempati posisi 12 besar penyelenggara negara terkaya di bawah posisi akbar tandjung.
#
# [Triple(source='vv1', relation='instance', target='aktivis'), Triple(source='vv2', relation='instance', target='damai'), Triple(source='vv3', relation='instance', target='mancanegara'), Triple(source='vv4', relation='instance', target='hari'), Triple(source='vv5', relation='instance', target='kamis'), Triple(source='vv6', relation='instance', target='hasil'), Triple(source='vv7', relation='instance', target='lalu'), Triple(source='vv8', relation='instance', target='tembus'), Triple(source='vv9', relation='instance', target='kepung'), Triple(source='vv10', relation='instance', target='israel'), Triple(source='vv11', relation='instance', target='masuk'), Triple(source='vv12', relation='instance', target='dan'), Triple(source='vv13', relation='instance', target='gereja'), Triple(source='vv14', relation='instance', target='dalam'), Triple(source='vv15', relation='instance', target='bawa'), Triple(source='vv16', relation='instance', target='makan'), Triple(source='vv17', relation='instance', target='obatobatan'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv1', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv6', relation='ARG1', target='vv8'), Triple(source='vv8', relation='ARG1', target='vv9'), Triple(source='vv9', relation='mod', target='vv10'), Triple(source='vv8', relation='mod', target='vv11'), Triple(source='vv11', relation='mod', target='vv12'), Triple(source='vv17', relation='mod', target='vv13'), Triple(source='vv11', relation='ARG1', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv11', relation='mod', target='vv16'), Triple(source='vv15', relation='ARG1', target='vv17'), Triple(source='vv16', relation='mod', target='vv18')]
# sejumlah aktivis perdamaian dari mancanegara hari kamis lalu berhasil menembus kepungan israel dan masuk ke dalam gereja dengan membawa makanan dan obat-obatan.
#
# [Triple(source='vv1', relation='instance', target='buka'), Triple(source='vv2', relation='instance', target='hari'), Triple(source='vv3', relation='instance', target='jelang'), Triple(source='vv4', relation='instance', target='akhir'), Triple(source='vv5', relation='instance', target='liga'), Triple(source='vv6', relation='instance', target='italia'), Triple(source='vv7', relation='instance', target='seri'), Triple(source='vv8', relation='instance', target='a'), Triple(source='vv9', relation='instance', target='dan'), Triple(source='vv10', relation='instance', target='saat'), Triple(source='vv11', relation='instance', target='buru'), Triple(source='vv12', relation='instance', target='gelar'), Triple(source='vv13', relation='instance', target='juara'), Triple(source='vv14', relation='instance', target='masih'), Triple(source='vv15', relation='instance', target='tekan'), Triple(source='vv16', relation='instance', target='main'), Triple(source='vv17', relation='instance', target='as'), Triple(source='vv18', relation='instance', target='roma'), Triple(source='vv19', relation='instance', target='berat'), Triple(source='vv20', relation='instance', target='makin'), Triple(source='vv1', relation='time', target='vv2'), Triple(source='vv3', relation='ARG1', target='vv3'), Triple(source='vv4', relation='mod', target='vv4'), Triple(source='vv5', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv7', relation='mod', target='vv7'), Triple(source='vv1', relation='mod', target='vv8'), Triple(source='vv1', relation='ARG1', target='vv9'), Triple(source='vv10', relation='mod', target='vv10'), Triple(source='vv11', relation='mod', target='vv11'), Triple(source='vv12', relation='mod', target='vv12'), Triple(source='vv1', relation='mod', target='vv13'), Triple(source='vv1', relation='ARG1', target='vv14'), Triple(source='vv15', relation='mod', target='vv15'), Triple(source='vv16', relation='mod', target='vv16'), Triple(source='vv17', relation='mod', target='vv17'), Triple(source='vv16', relation='mod', target='vv18'), Triple(source='vv19', relation='mod', target='vv19')]
# sehari menjelang berakhirnya liga italia seri a, dan saat perburuan gelar juara masih terbuka, tekanan terhadap para pemain as roma semakin berat.
#
# [Triple(source='vv1', relation='instance', target='sebut'), Triple(source='vv2', relation='instance', target='bukti'), Triple(source='vv3', relation='instance', target='sejarah'), Triple(source='vv4', relation='instance', target='tentang'), Triple(source='vv5', relation='instance', target='syekh'), Triple(source='vv6', relation='instance', target='siti'), Triple(source='vv7', relation='instance', target='jenar'), Triple(source='vv8', relation='instance', target='tanah'), Triple(source='vv9', relation='instance', target='merah'), Triple(source='vv10', relation='instance', target='lemah'), Triple(source='vv11', relation='instance', target='atau'), Triple(source='vv12', relation='instance', target='abang'), Triple(source='vv13', relation='instance', target='orang'), Triple(source='vv14', relation='instance', target='simpang'), Triple(source='vv15', relation='instance', target='tasawuf'), Triple(source='vv16', relation='instance', target='suni'), Triple(source='vv17', relation='instance', target='atas'), Triple(source='vv18', relation='instance', target='hukum'), Triple(source='vv19', relation='instance', target='dan'), Triple(source='vv20', relation='instance', target='itu'), Triple(source='vv21', relation='instance', target='mati'), Triple(source='vv22', relation='instance', target='wali'), Triple(source='vv23', relation='instance', target='sanga'), Triple(source='vv24', relation='instance', target='sembilan'), Triple(source='vv1', relation='ARG1', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv2', relation='mod', target='vv4'), Triple(source='vv1', relation='ARG1', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv7', relation='mod', target='vv8'), Triple(source='vv8', relation='mod', target='vv9'), Triple(source='vv9', relation='mod', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv10', relation='mod', target='vv12'), Triple(source='vv1', relation='ARG1', target='vv13'), Triple(source='vv13', relation='mod', target='vv14'), Triple(source='vv14', relation='ARG1', target='vv15'), Triple(source='vv15', relation='mod', target='vv16'), Triple(source='vv15', relation='mod', target='vv17'), Triple(source='vv14', relation='mod', target='vv18'), Triple(source='vv18', relation='mod', target='vv19'), Triple(source='vv18', relation='ARG1', target='vv20'), Triple(source='vv18', relation='mod', target='vv21'), Triple(source='vv18', relation='location', target='vv22'), Triple(source='vv23', relation='mod', target='vv23'), Triple(source='vv22', relation='mod', target='vv24'), Triple(source='vv22', relation='mod', target='vv25')]
# sebagai bukti sejarah atas penentangan mereka itu, disebutkan syekh siti jenar (tanah merah atau lemah abang) sebagai orang yang menyimpang dari tasawuf suni di atas, dan karena itu dihukum mati oleh para wali sanga (wali sembilan).
#
# [Triple(source='vv1', relation='instance', target='jenis'), Triple(source='vv2', relation='instance', target='dua'), Triple(source='vv3', relation='instance', target='kirim'), Triple(source='vv4', relation='instance', target='hewan'), Triple(source='vv5', relation='instance', target='piara'), Triple(source='vv6', relation='instance', target='hari'), Triple(source='vv7', relation='instance', target='mulai'), Triple(source='vv8', relation='instance', target='kembali'), Triple(source='vv9', relation='instance', target='negara'), Triple(source='vv10', relation='instance', target='tuan'), Triple(source='vv11', relation='instance', target='asal'), Triple(source='vv12', relation='instance', target='benua'), Triple(source='vv13', relation='instance', target='amerika'), Triple(source='vv14', relation='instance', target='sana'), Triple(source='vv3', relation='ARG1', target='vv1'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='mod', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv1', relation='mod', target='vv6'), Triple(source='vv3', relation='mod', target='vv7'), Triple(source='vv3', relation='mod', target='vv8'), Triple(source='vv3', relation='location', target='vv9'), Triple(source='vv9', relation='mod', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv10', relation='mod', target='vv12'), Triple(source='vv13', relation='mod', target='vv13')]
# dua jenis hewan piaraan itu sejak beberapa hari ini mulai dikirim kembali ke negara asal tuannya di benua amerika sana.
#
# [Triple(source='vv1', relation='instance', target='jadi'), Triple(source='vv2', relation='instance', target='namun'), Triple(source='vv3', relation='instance', target='timbul'), Triple(source='vv4', relation='instance', target='ledak'), Triple(source='vv5', relation='instance', target='bom'), Triple(source='vv6', relation='instance', target='malam'), Triple(source='vv7', relation='instance', target='natal'), Triple(source='vv8', relation='instance', target='lalu'), Triple(source='vv9', relation='instance', target='nyata'), Triple(source='vv10', relation='instance', target='masih'), Triple(source='vv11', relation='instance', target='trauma'), Triple(source='vv12', relation='instance', target='dalam'), Triple(source='vv13', relation='instance', target='warga'), Triple(source='vv14', relation='instance', target='singapura'), Triple(source='vv15', relation='instance', target='datang'), Triple(source='vv16', relation='instance', target='pulau'), Triple(source='vv17', relation='instance', target='batam'), Triple(source='vv3', relation='ARG0', target='vv1'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv1', relation='mod', target='vv5'), Triple(source='vv4', relation='ARG1', target='vv6'), Triple(source='vv1', relation='time', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv3', relation='mod', target='vv9'), Triple(source='vv3', relation='mod', target='vv10'), Triple(source='vv3', relation='mod', target='vv11'), Triple(source='vv3', relation='ARG1', target='vv12'), Triple(source='vv11', relation='mod', target='vv13'), Triple(source='vv11', relation='mod', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv3', relation='ARG1', target='vv16'), Triple(source='vv15', relation='location', target='vv17'), Triple(source='vv16', relation='mod', target='vv18')]
# namun, kejadian peledakan bom yang terjadi pada malam natal lalu ternyata masih menimbulkan trauma mendalam bagi warga singapura untuk datang ke pulau batam.
#
# [Triple(source='vv1', relation='instance', target='sementara'), Triple(source='vv2', relation='instance', target='itu'), Triple(source='vv3', relation='instance', target='nyata'), Triple(source='vv4', relation='instance', target='panglima'), Triple(source='vv5', relation='instance', target='komando'), Triple(source='vv6', relation='instance', target='operasi'), Triple(source='vv7', relation='instance', target='tni'), Triple(source='vv8', relation='instance', target='au'), Triple(source='vv9', relation='instance', target='koopsau'), Triple(source='vv10', relation='instance', target='i'), Triple(source='vv11', relation='instance', target='marsekal'), Triple(source='vv12', relation='instance', target='muda'), Triple(source='vv13', relation='instance', target='soetrisno'), Triple(source='vv14', relation='instance', target='jadi'), Triple(source='vv15', relation='instance', target='mpr'), Triple(source='vv16', relation='instance', target='ada'), Triple(source='vv17', relation='instance', target='darurat'), Triple(source='vv18', relation='instance', target='wilayah'), Triple(source='vv19', relation='instance', target='pangkal'), Triple(source='vv20', relation='instance', target='udara'), Triple(source='vv21', relation='instance', target='halim'), Triple(source='vv22', relation='instance', target='perdanakusuma'), Triple(source='vv23', relation='instance', target='jakarta'), Triple(source='vv24', relation='instance', target='siap'), Triple(source='vv25', relation='instance', target='evakuasi'), Triple(source='vv26', relation='instance', target='anggota'), Triple(source='vv27', relation='instance', target='senayan'), Triple(source='vv1', relation='mod', target='vv1'), Triple(source='vv3', relation='ARG0', target='vv3'), Triple(source='vv4', relation='mod', target='vv4'), Triple(source='vv5', relation='mod', target='vv5'), Triple(source='vv6', relation='mod', target='vv6'), Triple(source='vv11', relation='mod', target='vv7'), Triple(source='vv16', relation='mod', target='vv8'), Triple(source='vv7', relation='mod', target='vv9'), Triple(source='vv7', relation='mod', target='vv10'), Triple(source='vv7', relation='mod', target='vv11'), Triple(source='vv8', relation='mod', target='vv12'), Triple(source='vv18', relation='mod', target='vv13'), Triple(source='vv9', relation='mod', target='vv14'), Triple(source='vv9', relation='mod', target='vv15'), Triple(source='vv9', relation='mod', target='vv16'), Triple(source='vv11', relation='mod', target='vv17'), Triple(source='vv8', relation='mod', target='vv18'), Triple(source='vv3', relation='mod', target='vv19'), Triple(source='vv14', relation='location', target='vv20'), Triple(source='vv26', relation='mod', target='vv21'), Triple(source='vv14', relation='ARG1', target='vv22'), Triple(source='vv16', relation='mod', target='vv23'), Triple(source='vv7', relation='mod', target='vv24'), Triple(source='vv16', relation='mod', target='vv25'), Triple(source='vv19', relation='location', target='vv26'), Triple(source='vv19', relation='mod', target='vv27'), Triple(source='vv20', relation='mod', target='vv28'), Triple(source='vv21', relation='mod', target='vv29'), Triple(source='vv22', relation='mod', target='vv30'), Triple(source='vv23', relation='mod', target='vv31'), Triple(source='vv14', relation='mod', target='vv32'), Triple(source='vv25', relation='ARG0', target='vv33'), Triple(source='vv26', relation='mod', target='vv34')]
# sementara itu, panglima komando operasi tni au (koopsau) i marsekal muda tni au soetrisno menyatakan, apabila dalam si mpr terjadi keadaan darurat, tni au wilayah koopsau i yang berpangkalan di pangkalan udara halim perdanakusuma, jakarta, siap mengevakuasi anggota mpr dari senayan.
#
# ...
# sekitar satu jam kemudian terdengar ledakan kedua yang menyebabkan satu dari dua gedung kembar itu runtuh, luluh lantak, rata dengan tanah.
#
# [Triple(source='vv1', relation='instance', target='evaluasi'), Triple(source='vv2', relation='instance', target='data'), Triple(source='vv3', relation='instance', target='lansir'), Triple(source='vv4', relation='instance', target='forum'), Triple(source='vv5', relation='instance', target='komunikasi'), Triple(source='vv6', relation='instance', target='massa'), Triple(source='vv7', relation='instance', target='fkmforum'), Triple(source='vv8', relation='instance', target='wartawan'), Triple(source='vv9', relation='instance', target='dpryang'), Triple(source='vv10', relation='instance', target='tahun'), Triple(source='vv11', relation='instance', target='tingkat'), Triple(source='vv12', relation='instance', target='hadir'), Triple(source='vv13', relation='instance', target='anggota'), Triple(source='vv14', relation='instance', target='dpr'), Triple(source='vv15', relation='instance', target='sama'), Triple(source='vv16', relation='instance', target='saja'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv3', relation='ARG1', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv7', relation='mod', target='vv8'), Triple(source='vv8', relation='mod', target='vv9'), Triple(source='vv8', relation='mod', target='vv10'), Triple(source='vv11', relation='mod', target='vv11'), Triple(source='vv1', relation='ARG1', target='vv12'), Triple(source='vv11', relation='mod', target='vv13'), Triple(source='vv12', relation='mod', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv10', relation='mod', target='vv16'), Triple(source='vv10', relation='mod', target='vv17')]
# data yang dilansir forum komunikasi massa (fkm)-forum wartawan dpr-yang tiap tahun mengevaluasi tingkat kehadiran anggota dpr, tiap tahun sama saja.
#
# [Triple(source='vv1', relation='instance', target='minta'), Triple(source='vv2', relation='instance', target='kait'), Triple(source='vv3', relation='instance', target='mendagri'), Triple(source='vv4', relation='instance', target='juga'), Triple(source='vv5', relation='instance', target='daerah'), Triple(source='vv6', relation='instance', target='lebih'), Triple(source='vv7', relation='instance', target='tidak'), Triple(source='vv8', relation='instance', target='pacu'), Triple(source='vv9', relation='instance', target='dapat'), Triple(source='vv10', relation='instance', target='asli'), Triple(source='vv11', relation='instance', target='pad'), Triple(source='vv12', relation='instance', target='rugi'), Triple(source='vv13', relation='instance', target='dunia'), Triple(source='vv14', relation='instance', target='usaha'), Triple(source='vv15', relation='instance', target='dan'), Triple(source='vv16', relation='instance', target='tetangga'), Triple(source='vv1', relation='ARG1', target='vv2'), Triple(source='vv1', relation='ARG0', target='vv3'), Triple(source='vv1', relation='mod', target='vv4'), Triple(source='vv1', relation='ARG1', target='vv5'), Triple(source='vv9', relation='mod', target='vv6'), Triple(source='vv13', relation='mod', target='vv7'), Triple(source='vv5', relation='mod', target='vv8'), Triple(source='vv6', relation='mod', target='vv9'), Triple(source='vv6', relation='mod', target='vv10'), Triple(source='vv8', relation='ARG1', target='vv11'), Triple(source='vv9', relation='mod', target='vv12'), Triple(source='vv5', relation='mod', target='vv13'), Triple(source='vv1', relation='ARG1', target='vv14'), Triple(source='vv12', relation='ARG1', target='vv15'), Triple(source='vv13', relation='mod', target='vv16'), Triple(source='vv5', relation='mod', target='vv17'), Triple(source='vv5', relation='mod', target='vv18')]
# dalam kaitan itu, mendagri juga meminta daerah untuk tidak berlebihan dalam memacu pendapatan asli daerah (pad) sehingga merugikan dunia usaha dan daerah tetangganya.
#
# [Triple(source='vv1', relation='instance', target='ada'), Triple(source='vv2', relation='instance', target='namun'), Triple(source='vv3', relation='instance', target='sama'), Triple(source='vv4', relation='instance', target='tidak'), Triple(source='vv5', relation='instance', target='pergi'), Triple(source='vv6', relation='instance', target='tokoh'), Triple(source='vv7', relation='instance', target='panutan'), Triple(source='vv8', relation='instance', target='tahun'), Triple(source='vv9', relation='instance', target='awal'), Triple(source='vv10', relation='instance', target='1980'), Triple(source='vv11', relation='instance', target='pemuda'), Triple(source='vv12', relation='instance', target='banyak'), Triple(source='vv13', relation='instance', target='desa'), Triple(source='vv14', relation='instance', target='berbondongbondong'), Triple(source='vv15', relation='instance', target='malaysia'), Triple(source='vv16', relation='instance', target='cari'), Triple(source='vv17', relation='instance', target='ladang'), Triple(source='vv18', relation='instance', target='dua'), Triple(source='vv19', relation='instance', target='tandus'), Triple(source='vv5', relation='ARG1', target='vv1'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv1', relation='mod', target='vv3'), Triple(source='vv1', relation='mod', target='vv4'), Triple(source='vv1', relation='ARG1', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv1', relation='ARG1', target='vv8'), Triple(source='vv8', relation='mod', target='vv9'), Triple(source='vv8', relation='mod', target='vv10'), Triple(source='vv5', relation='ARG0', target='vv11'), Triple(source='vv11', relation='mod', target='vv12'), Triple(source='vv11', relation='mod', target='vv13'), Triple(source='vv19', relation='mod', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv5', relation='location', target='vv16'), Triple(source='vv5', relation='ARG1', target='vv17'), Triple(source='vv16', relation='ARG1', target='vv18'), Triple(source='vv19', relation='ARG1', target='vv19'), Triple(source='vv17', relation='mod', target='vv20'), Triple(source='vv16', relation='mod', target='vv21')]
# namun, bersamaan dengan tidak adanya tokoh panutan ini, sekitar awal tahun 1980, banyak pemuda desa berbondong-bondong pergi ke malaysia mencari ladang kedua karena tandusnya ladang di desa.
#
# [Triple(source='vv1', relation='instance', target='nyata'), Triple(source='vv2', relation='instance', target='mantan'), Triple(source='vv3', relation='instance', target='menteri'), Triple(source='vv4', relation='instance', target='sekretaris'), Triple(source='vv5', relation='instance', target='negara'), Triple(source='vv6', relation='instance', target='mensesneg'), Triple(source='vv7', relation='instance', target='akbar'), Triple(source='vv8', relation='instance', target='tandjung'), Triple(source='vv9', relation='instance', target='senin'), Triple(source='vv10', relation='instance', target='154'), Triple(source='vv11', relation='instance', target='terima'), Triple(source='vv12', relation='instance', target='pernah'), Triple(source='vv13', relation='instance', target='dana'), Triple(source='vv14', relation='instance', target='bentuk'), Triple(source='vv15', relation='instance', target='cek'), Triple(source='vv16', relation='instance', target='badan'), Triple(source='vv17', relation='instance', target='urus'), Triple(source='vv18', relation='instance', target='logistik'), Triple(source='vv19', relation='instance', target='bulog'), Triple(source='vv20', relation='instance', target='serah'), Triple(source='vv21', relation='instance', target='deputi'), Triple(source='vv22', relation='instance', target='uang'), Triple(source='vv23', relation='instance', target='achmad'), Triple(source='vv24', relation='instance', target='ruskandar'), Triple(source='vv25', relation='instance', target='terus'), Triple(source='vv26', relation='instance', target='tetapi'), Triple(source='vv27', relation='instance', target='langsung'), Triple(source='vv28', relation='instance', target='yayasan'), Triple(source='vv29', relation='instance', target='raudlatul'), Triple(source='vv30', relation='instance', target='jannah'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv2', relation='mod', target='vv3'), Triple(source='vv3', relation='mod', target='vv4'), Triple(source='vv4', relation='mod', target='vv5'), Triple(source='vv5', relation='mod', target='vv6'), Triple(source='vv6', relation='mod', target='vv7'), Triple(source='vv6', relation='mod', target='vv8'), Triple(source='vv8', relation='mod', target='vv9'), Triple(source='vv9', relation='mod', target='vv10'), Triple(source='vv1', relation='ARG1', target='vv11'), Triple(source='vv11', relation='mod', target='vv12'), Triple(source='vv11', relation='ARG1', target='vv13'), Triple(source='vv25', relation='ARG1', target='vv14'), Triple(source='vv13', relation='mod', target='vv15'), Triple(source='vv14', relation='mod', target='vv16'), Triple(source='vv14', relation='mod', target='vv17'), Triple(source='vv16', relation='mod', target='vv18'), Triple(source='vv17', relation='mod', target='vv19'), Triple(source='vv18', relation='mod', target='vv20'), Triple(source='vv22', relation='mod', target='vv21'), Triple(source='vv16', relation='mod', target='vv22'), Triple(source='vv20', relation='location', target='vv23'), Triple(source='vv21', relation='ARG1', target='vv24'), Triple(source='vv19', relation='mod', target='vv25'), Triple(source='vv23', relation='mod', target='vv26'), Triple(source='vv20', relation='mod', target='vv27'), Triple(source='vv25', relation='mod', target='vv28'), Triple(source='vv25', relation='mod', target='vv29'), Triple(source='vv25', relation='location', target='vv30'), Triple(source='vv28', relation='mod', target='vv31'), Triple(source='vv29', relation='mod', target='vv32')]
# mantan menteri sekretaris negara (mensesneg) akbar tandjung, senin (15/4), menyatakan, pernah menerima dana dalam bentuk cek dari badan urusan logistik (bulog) yang diserahkan oleh deputi keuangan bulog achmad ruskandar, tetapi dana itu langsung diteruskan kepada yayasan raudlatul jannah.
#
# [Triple(source='vv1', relation='instance', target='pakat'), Triple(source='vv2', relation='instance', target='sangkut'), Triple(source='vv3', relation='instance', target='substansi'), Triple(source='vv4', relation='instance', target='ruu'), Triple(source='vv5', relation='instance', target='tindak'), Triple(source='vv6', relation='instance', target='pidana'), Triple(source='vv7', relation='instance', target='cuci'), Triple(source='vv8', relation='instance', target='uang'), Triple(source='vv9', relation='instance', target='nyata'), Triple(source='vv10', relation='instance', target='yusril'), Triple(source='vv11', relation='instance', target='hasil'), Triple(source='vv12', relation='instance', target='bahas'), Triple(source='vv13', relation='instance', target='dpr'), Triple(source='vv14', relation='instance', target='wakil'), Triple(source='vv15', relation='instance', target='dan'), Triple(source='vv16', relation='instance', target='pemerintah'), Triple(source='vv17', relation='instance', target='akhir'), Triple(source='vv18', relation='instance', target='ada'), Triple(source='vv19', relation='instance', target='ubah'), Triple(source='vv20', relation='instance', target='tambah'), Triple(source='vv21', relation='instance', target='erti'), Triple(source='vv1', relation='mod', target='vv2'), Triple(source='vv20', relation='mod', target='vv3'), Triple(source='vv2', relation='ARG1', target='vv4'), Triple(source='vv3', relation='mod', target='vv5'), Triple(source='vv4', relation='mod', target='vv6'), Triple(source='vv21', relation='mod', target='vv7'), Triple(source='vv5', relation='mod', target='vv8'), Triple(source='vv5', relation='mod', target='vv9'), Triple(source='vv6', relation='mod', target='vv10'), Triple(source='vv6', relation='mod', target='vv11'), Triple(source='vv7', relation='ARG1', target='vv12'), Triple(source='vv7', relation='ARG1', target='vv13'), Triple(source='vv3', relation='mod', target='vv14'), Triple(source='vv9', relation='ARG0', target='vv15'), Triple(source='vv9', relation='ARG1', target='vv16'), Triple(source='vv11', relation='mod', target='vv17'), Triple(source='vv11', relation='mod', target='vv18'), Triple(source='vv13', relation='mod', target='vv19'), Triple(source='vv14', relation='mod', target='vv20'), Triple(source='vv20', relation='mod', target='vv21'), Triple(source='vv14', relation='mod', target='vv22'), Triple(source='vv1', relation='mod', target='vv23'), Triple(source='vv1', relation='ARG1', target='vv24'), Triple(source='vv18', relation='mod', target='vv25'), Triple(source='vv19', relation='mod', target='vv26'), Triple(source='vv2', relation='ARG0', target='vv27')]
# menyangkut substansi dari ruu tindak pidana pencucian uang tersebut, yusril menyatakan dari hasil pembahasan antara dpr dan wakil pemerintah, akhirnya disepakati adanya perubahan dan penambahan menyangkut pengertian tindak pidana pencucian uang.
#
# [Triple(source='vv1', relation='instance', target='jelas'), Triple(source='vv2', relation='instance', target='ustadz'), Triple(source='vv3', relation='instance', target='sholeh'), Triple(source='vv4', relation='instance', target='ibrahim'), Triple(source='vv5', relation='instance', target='depan'), Triple(source='vv6', relation='instance', target='santri'), Triple(source='vv7', relation='instance', target='ada'), Triple(source='vv8', relation='instance', target='timbang'), Triple(source='vv9', relation='instance', target='aman'), Triple(source='vv10', relation='instance', target='mungkin'), Triple(source='vv11', relation='instance', target='dan'), Triple(source='vv12', relation='instance', target='benturanbenturan'), Triple(source='vv13', relation='instance', target='pihak'), Triple(source='vv14', relation='instance', target='lain'), Triple(source='vv15', relation='instance', target='batal'), Triple(source='vv16', relation='instance', target='demo'), Triple(source='vv1', relation='ARG0', target='vv2'), Triple(source='vv3', relation='mod', target='vv3'), Triple(source='vv2', relation='mod', target='vv4'), Triple(source='vv5', relation='mod', target='vv5'), Triple(source='vv1', relation='ARG1', target='vv6'), Triple(source='vv10', relation='ARG1', target='vv7'), Triple(source='vv7', relation='mod', target='vv8'), Triple(source='vv8', relation='mod', target='vv9'), Triple(source='vv1', relation='ARG1', target='vv10'), Triple(source='vv10', relation='mod', target='vv11'), Triple(source='vv7', relation='mod', target='vv12'), Triple(source='vv12', relation='mod', target='vv13'), Triple(source='vv13', relation='mod', target='vv14'), Triple(source='vv1', relation='mod', target='vv15'), Triple(source='vv15', relation='ARG1', target='vv16')]
# ustadz sholeh ibrahim di depan seluruh santri menjelaskan, setelah adanya pertimbangan keamanan dan karena dimungkinkan adanya benturan-benturan pihak lain, maka demo ini dibatalkan.
