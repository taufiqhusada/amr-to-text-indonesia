# %%
# !pip install transformers==4.12.5 sentencepiece==0.1.96 sacrebleu
# Out:
# Collecting transformers==4.12.5
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 7.4 MB/s
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.0 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 12.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 58.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (3.4.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 68.5 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 77.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (4.10.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.12.5) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.12.5) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.12.5) (3.0.6)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.12.5) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.12.5) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.5) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.5) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.12.5) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, portalocker, huggingface-hub, colorama, transformers, sentencepiece, sacrebleu
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed colorama-0.4.4 huggingface-hub-0.4.0 portalocker-2.3.2 pyyaml-6.0 sacrebleu-2.0.0 sacremoses-0.0.47 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.12.5

# %%
# !git clone https://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@github.com/taufiqhusada/amr-to-text-indonesia.git
# Out:
# Cloning into 'amr-to-text-indonesia'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 35 (delta 9), reused 30 (delta 7), pack-reused 0
# Unpacking objects: 100% (35/35), done.

# %%
import pandas as pd
import os
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from transformers.optimization import  AdamW, Adafactor 
import time
import warnings
from tqdm import tqdm
from sacrebleu import corpus_bleu
import random
import numpy as np
warnings.filterwarnings('ignore')

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0") 
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
set_seed(42)

# %%
tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base", return_dict=True)

#moving the model to device(GPU/CPU)
model.to(device)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
AMR_TOKENS = [':wiki', ':ARG5', ':time-of', ':age', ':duration', ':year', ':mod', ':ARG1-of', ':manner-of',
                          ':snt7', ':year2', ':op5', ':subset-of', ':dayperiod', ':quant', ':season', ':subevent',
                          ':op9', ':accompanier', ':op6', ':li', ':direction-of', ':op13', ':op11', ':op4',
                          ':condition', ':op16', ':condition-of', ':ARG8', ':domain', ':time', ':weekday', ':ARG2',
                          ':poss', ':beneficiary-of', ':prep-by', ':snt2', ':prep-in', ':snt8', ':concession-of',
                          ':topic-of', ':scale', ':snt6', ':ARG3', ':prep-for', ':s', ':medium', ':op2', ':prep-on',
                          ':beneficiary', ':snt11', ':op7', ':prep-as', ':ARG2-of', ':frequency-of', ':ARG7', ':unit',
                          ':op1', ':path', ':value', ':degree-of', ':direction', ':poss-of', ':ord', ':month', ':op10',
                          ':quarter', ':op14', ':prep-under', ':snt3', ':prep-against', ':ARG6', ':location',
                          ':destination', ':consist-of', ':purpose', ':degree', ':extent', ':snt1', ':extent-of',
                          ':domain-of', ':op8', ':conj-as-if', ':prep-from', ':ord-of', ':snt10', ':snt9',
                          ':duration-of', ':ARG5-of', ':topic', ':calendar', ':prep-at', ':polite', ':accompanier-of',
                          ':example', ':prep-out-of', ':day', ':name-of', ':prep-amid', ':prep-into', ':concession',
                          ':part', ':destination-of', ':ARG9', ':ARG0', ':op1-of', ':op19', ':century', ':prep-among',
                          ':example-of', ':instrument', ':source', ':op17', ':medium-of', ':prep-with', ':compared-to',
                          ':quant-of', ':prep-in-addition-to', ':purpose-of', ':instrument-of', ':snt5', ':frequency',
                          ':timezone', ':op3', ':prep-toward', ':ARG3-of', ':prep-on-behalf-of', ':prep-without',
                          ':name', ':op15', ':prep-along-with', ':ARG4', ':mode', ':prep-to', ':decade', ':ARG4-of',
                          ':subevent-of', ':age-of', ':op12', ':polarity', ':range', ':snt4', ':P', ':part-of',
                          ':location-of', ':manner', ':ARG0-of', ':op18', ':source-of', ':op20', ':era', ':ARG1',
                          ':path-of']
T5_PREFIX = 'translate Graph to English: '

# %%
new_tokens_vocab = {}
new_tokens_vocab['additional_special_tokens'] = []
for idx, t in enumerate(AMR_TOKENS):
    new_tokens_vocab['additional_special_tokens'].append(t)

num_added_toks = tokenizer.add_special_tokens(new_tokens_vocab)
print(f'added {num_added_toks} tokens')

model.resize_token_embeddings(len(tokenizer))
# Out:
# added 153 tokens
# Embedding(32253, 768)

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='t5-base', vocab_size=32100, model_max_len=512, is_fast=True, padding_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'additional_special_tokens': [':wiki', ':ARG5', ':time-of', ':age', ':duration', ':year', ':mod', ':ARG1-of', ':manner-of', ':snt7', ':year2', ':op5', ':subset-of', ':dayperiod', ':quant', ':season', ':subevent', ':op9', ':accompanier', ':op6', ':li', ':direction-of', ':op13', ':op11', ':op4', ':condition', ':op16', ':condition-of', ':ARG8', ':domain', ':time', ':weekday', ':ARG2', ':poss', ':beneficiary-of', ':prep-by', ':snt2', ':prep-in', ':snt8', ':concession-of', ':topic-of', ':scale', ':snt6', ':ARG3', ':prep-for', ':s', ':medium', ':op2', ':prep-on', ':beneficiary', ':snt11', ':op7', ':prep-as', ':ARG2-of', ':frequency-of', ':ARG7', ':unit', ':op1', ':path', ':value', ':degree-of', ':direction', ':poss-of', ':ord', ':month', ':op10', ':quarter', ':op14', ':prep-under', ':snt3', ':prep-against', ':ARG6', ':location', ':destination', ':consist-of', ':purpose', ':degree', ':extent', ':snt1', ':extent-of', ':domain-of', ':op8', ':conj-as-if', ':prep-from', ':ord-of', ':snt10', ':snt9', ':duration-of', ':ARG5-of', ':topic', ':calendar', ':prep-at', ':polite', ':accompanier-of', ':example', ':prep-out-of', ':day', ':name-of', ':prep-amid', ':prep-into', ':concession', ':part', ':destination-of', ':ARG9', ':ARG0', ':op1-of', ':op19', ':century', ':prep-among', ':example-of', ':instrument', ':source', ':op17', ':medium-of', ':prep-with', ':compared-to', ':quant-of', ':prep-in-addition-to', ':purpose-of', ':instrument-of', ':snt5', ':frequency', ':timezone', ':op3', ':prep-toward', ':ARG3-of', ':prep-on-behalf-of', ':prep-without', ':name', ':op15', ':prep-along-with', ':ARG4', ':mode', ':prep-to', ':decade', ':ARG4-of', ':subevent-of', ':age-of', ':op12', ':polarity', ':range', ':snt4', ':P', ':part-of', ':location-of', ':manner', ':ARG0-of', ':op18', ':source-of', ':op20', ':era', ':ARG1', ':path-of']})

# %%
model.config
# Out:
# T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.12.5",
#   "use_cache": true,
#   "vocab_size": 32253
# }

# %%
from torch.utils.data import Dataset, DataLoader

# class to load preprocessed amr data
class AMRToTextDataset(Dataset):    
    def __init__(self, file_amr_path, file_sent_path, tokenizer, split):
        temp_list_amr_input = []
        with open(file_amr_path) as f:
            temp_list_amr_input = f.readlines()
        list_amr_input = []
        for item in temp_list_amr_input:
            list_amr_input.append(item.strip())
            
        temp_list_sent_output = []
        with open(file_sent_path) as f:
            temp_list_sent_output = f.readlines()
        list_sent_output = []
        for item in temp_list_sent_output:
            list_sent_output.append(item.strip())
        
        df = pd.DataFrame(list(zip(list_amr_input, list_sent_output)), columns = ['amr','sent'])
        self.data = df
        self.tokenizer = tokenizer
 
    
    def __getitem__(self, index):
        data = self.data.loc[index,:]
        amr, sent = data['amr'], data['sent']
       
        tokenize_amr = self.tokenizer.encode(amr, add_special_tokens=False)
        tokenize_sent = self.tokenizer.encode(sent, add_special_tokens=False)
        
        item = {'input':{}, 'output':{}}
        item['input']['encoded'] = tokenize_amr
        item['input']['raw'] = amr
        item['output']['encoded'] = tokenize_sent
        item['output']['raw'] = sent
        return item
    
    def __len__(self):
        return len(self.data)
    
## Data loader class
class AMRToTextDataLoader(DataLoader):
    def __init__(self, max_seq_len=384, label_pad_token_id=-100, model_type='t5', tokenizer=None, *args, **kwargs):
        super(AMRToTextDataLoader, self).__init__(*args, **kwargs)
        self.tokenizer = tokenizer
        self.max_seq_len = max_seq_len
        self.label_pad_token_id = label_pad_token_id
        
        self.pad_token_id = tokenizer.pad_token_id
        self.bos_token_id = tokenizer.pad_token_id
        self.eos_token_id = tokenizer.eos_token_id
        
        if model_type == 't5':
            if self.tokenizer is not None:
                self.t5_prefix =np.array(self.tokenizer.encode(f'translate Graph to English: ', add_special_tokens=False))
            self.collate_fn = self._t5_collate_fn
            
    def _t5_collate_fn(self, batch):
        batch_size = len(batch)
        max_enc_len = min(self.max_seq_len, max(map(lambda x: len(x['input']['encoded']), batch))  + len(self.t5_prefix))
        max_dec_len = min(self.max_seq_len, max(map(lambda x: len(x['output']['encoded']), batch)) + 1)
        
        id_batch = []
        enc_batch = np.full((batch_size, max_enc_len), self.pad_token_id, dtype=np.int64)
        dec_batch = np.full((batch_size, max_dec_len), self.pad_token_id, dtype=np.int64)
        label_batch = np.full((batch_size, max_dec_len), self.label_pad_token_id, dtype=np.int64)
        enc_mask_batch = np.full((batch_size, max_enc_len), 0, dtype=np.float32)
        dec_mask_batch = np.full((batch_size, max_dec_len), 0, dtype=np.float32)
        
        for i, item in enumerate(batch):
            input_seq = item['input']['encoded']
            label_seq = item['output']['encoded']
            input_seq, label_seq = input_seq[:max_enc_len - len(self.t5_prefix)], label_seq[:max_dec_len - 1]
            
            # Assign content
            enc_batch[i,len(self.t5_prefix):len(self.t5_prefix) + len(input_seq)] = input_seq
            dec_batch[i,1:1+len(label_seq)] = label_seq
            label_batch[i,:len(label_seq)] = label_seq
            enc_mask_batch[i,:len(input_seq) + len(self.t5_prefix)] = 1
            dec_mask_batch[i,:len(label_seq) + 1] = 1
            
            # Assign special token to encoder input
            enc_batch[i,:len(self.t5_prefix)] = self.t5_prefix
            
            # Assign special token to decoder input
            dec_batch[i,0] = self.bos_token_id
            
            # Assign special token to label
            label_batch[i,len(label_seq)] = self.eos_token_id
            
        
        return enc_batch, dec_batch, enc_mask_batch, None, label_batch

# %%
DATA_FOLDER = '/content'

train_amr_path = os.path.join(DATA_FOLDER, 'train.source')
train_sent_path = os.path.join(DATA_FOLDER, 'train.target')

dev_amr_path = os.path.join(DATA_FOLDER, 'val.source')
dev_sent_path = os.path.join(DATA_FOLDER, 'val.target')

test_amr_path = os.path.join(DATA_FOLDER, 'test.source')
test_sent_path = os.path.join(DATA_FOLDER, 'test.target')

train_dataset = AMRToTextDataset(train_amr_path, train_sent_path, tokenizer, 'train')
dev_dataset = AMRToTextDataset(dev_amr_path, dev_sent_path, tokenizer, 'dev')
test_dataset = AMRToTextDataset(test_amr_path, test_sent_path, tokenizer, 'test')

model_type = 't5'
max_seq_len = 384
batch_size = 4
train_loader = AMRToTextDataLoader(dataset=train_dataset, model_type=model_type, tokenizer=tokenizer, max_seq_len=max_seq_len, 
                                    batch_size=batch_size, shuffle=False)  
test_loader = AMRToTextDataLoader(dataset=test_dataset, model_type=model_type, tokenizer=tokenizer, max_seq_len=max_seq_len, 
                                    batch_size=batch_size, shuffle=False)

# %%
print(len(train_dataset))
print(len(dev_dataset))
print(len(test_dataset))

print(len(train_loader))
# Out:
# 36521
# 1368
# 1371
# 9131

# %%
optimizer = AdamW(
    model.parameters(),
    lr=3e-5,
    eps=1e-8
)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

n_epochs = 4
num_beams = 5

# %%
# train
for epoch in range(n_epochs):
    model.train()
    torch.set_grad_enabled(True)
 
    total_train_loss = 0
    list_hyp, list_label = [], []

    train_pbar = tqdm(iter(train_loader), leave=True, total=len(train_loader))
    for i, batch_data in enumerate(train_pbar):
        enc_batch = torch.LongTensor(batch_data[0])
        dec_batch = torch.LongTensor(batch_data[1])
        enc_mask_batch = torch.FloatTensor(batch_data[2])
        dec_mask_batch = None
        label_batch = torch.LongTensor(batch_data[4])
        token_type_batch = None
        
        # cuda
        enc_batch = enc_batch.cuda()
        dec_batch = dec_batch.cuda()
        enc_mask_batch = enc_mask_batch.cuda() 
        dec_mask_batch = None
        label_batch = label_batch.cuda()
        token_type_batch = None

        outputs = model(input_ids=enc_batch, attention_mask=enc_mask_batch, decoder_input_ids=dec_batch, 
                    decoder_attention_mask=dec_mask_batch, labels=label_batch)
        loss, logits = outputs[:2]
        hyps = logits.topk(1, dim=-1)[1]
        
        loss.backward()
        
        tr_loss = loss.item()
        total_train_loss = total_train_loss + tr_loss
        
        train_pbar.set_description("(Epoch {}) TRAIN LOSS:{:.4f} LR:{:.8f}".format((epoch+1),
                total_train_loss/(i+1), get_lr(optimizer)))
        
        optimizer.step()
        optimizer.zero_grad()
# Out:
# (Epoch 1) TRAIN LOSS:4.2642 LR:0.00003000:   2%|▏         | 187/9131 [00:49<28:27,  5.24it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (729 > 512). Running this sequence through the model will result in indexing errors
# (Epoch 1) TRAIN LOSS:1.5815 LR:0.00003000: 100%|██████████| 9131/9131 [35:21<00:00,  4.30it/s]
# (Epoch 2) TRAIN LOSS:1.1651 LR:0.00003000: 100%|██████████| 9131/9131 [35:20<00:00,  4.31it/s]
# (Epoch 3) TRAIN LOSS:1.0269 LR:0.00003000: 100%|██████████| 9131/9131 [35:19<00:00,  4.31it/s]
# (Epoch 4) TRAIN LOSS:0.9335 LR:0.00003000: 100%|██████████| 9131/9131 [35:22<00:00,  4.30it/s]

# %%
# test on data test

model.eval()
torch.set_grad_enabled(False)

list_hyp, list_label = [], []

pbar = tqdm(iter(test_loader), leave=True, total=len(test_loader))
for i, batch_data in enumerate(pbar):
    batch_seq = batch_data[-1]

    enc_batch = torch.LongTensor(batch_data[0])
    dec_batch = torch.LongTensor(batch_data[1])
    enc_mask_batch = torch.FloatTensor(batch_data[2])
    dec_mask_batch = None
    label_batch = torch.LongTensor(batch_data[4])
    token_type_batch = None

    # cuda
    enc_batch = enc_batch.cuda()
    dec_batch = dec_batch.cuda()
    enc_mask_batch = enc_mask_batch.cuda() 
    dec_mask_batch = None
    label_batch = label_batch.cuda()
    token_type_batch = None

    hyps = model.generate(input_ids=enc_batch, attention_mask=enc_mask_batch, num_beams=num_beams, max_length=max_seq_len, 
                          early_stopping=True, pad_token_id=tokenizer.pad_token_id, eos_token_id=tokenizer.eos_token_id)

    batch_list_hyp = []
    batch_list_label = []
    for j in range(len(hyps)):
        hyp = hyps[j]
        label = label_batch[j,:].squeeze()
     
        batch_list_hyp.append(tokenizer.decode(hyp, skip_special_tokens=True))
        batch_list_label.append(tokenizer.decode(label[label != -100], skip_special_tokens=True))
    
    list_hyp += batch_list_hyp
    list_label += batch_list_label
# Out:
# 100%|██████████| 343/343 [06:18<00:00,  1.10s/it]

# %%
for i in range(len(list_hyp)):
    print(list_hyp[i], '----', list_label[i])
# Out:
# Support the thread's start resolutely. I replied to the poem's composition. ---- Resolutely support the thread starter! I compose a poem in reply:
# pledge to fight death to death to defend the Diaoyu Islands and related islands. ---- Pledge to fight to the death defending the Diaoyu Islands and the related islands
# Fishing boats are bumped into the fleet ; evil little ghosts of Japan stir up trouble and unrest ; they show their wolfish appearance again with stolen hearts and arrogant forms. ---- Fleets bumping fishing boats. Little evil Japanese ghosts stirring up trouble and unrest. With hearts of thieves and arrogant form, they again show their wolfish appearance
# Where is Homer Simpson when you need him? ---- Where's Homer Simpson when you need him?
# Doh, this is a major moment. ---- This is a major  D'oh! '' moment.
# Route 288, as we predicted, will generate residence development in a scarcely populated area around all exits of the road, overtaxing the local roads of the country. ---- As we predicted, Route 288 is generating residential development in scarcely populated areas all around its exits, overtaxing the local country roads.
# Other people choose where to work and where to live, but limited access highways can relieve traffic for drivers driving back and forth between Chesterfield County and Goochland County. ---- While the limited access highway might provide limited traffic relief for people driving back and forth between Chesterfield and Goochland counties, other people are making choices about where they live and work,
# and they created traffic congestion in new places. ---- and they are creating traffic congestion in new places.
# I was only surprised by this rapidity. ---- The only thing that surprises me is how rapidly this is happening.
# I even think it could lag 3 or 4 years. ---- Even I thought there might be a lag of three or four years.
# Think about the liability of creating all of Route 288's exits, Route 288 already created a $13 million road construction cost at just this one exit. ---- If Route 288 has already created a $ 13 million road - construction in just this one exist, think of the liability it has created for all of its exits!
# Another prediction. ---- Here's another prodiction :
# After a scattering development of subdivisions and the approval of mega commerce projects at the intersection of the 288 and major roads in the next few years, the need for new road improvements will soar. ---- After a few more years of scattered subdivision development and approval of mega-commercial projects at major 288 intersections, the need for new road improvements will soar.
# We can see well before the end of the decade that unfunded liabilities will zoom well past the 400 million dollars it took to build the original highway. ---- Before the end of the decade, we may well see the unfunded liability zoom well past the original $ 400 million it took to build the original highway.
# The idea was said by a brainiac who thought the Route 288 was such a great idea. ---- To the brainiacs who thought Route 288 was such a great idea :
# Thank you for nothing. ---- Thanks for nothing.
# I think we could spend 400 million dollars elsewhere better. ---- I think we could have spent the $ 400 million better elsewhere.
# I don't think you should blame the 288 road for creating those people. ---- I don't think you can blame 288 for creating those people.
# What is the alternative, if they have enough to create traffic congestion in new places? ---- If there enough of them to create new traffic congestion in new places, then what is the alternative?
# Additional traffic congestion in the old place? ---- Additional traffic congestion in old places?
# Now, you understand how people like TMT in Fairfax feel. ---- Now you understand how people like TMT in Fairfax feel.
# I usually take a pro-road position. ---- I 'd usually take the pro-road position -
# But the 288 is definitely an excess, despite the glaring need in other states. ---- but with the glaring needs in other parts of the state, 288 was definitely excess...
# Richmond has virtually no traffic. ---- You have a city, Richmond, that has virtually no traffic.
# The rush hour lasted 30 minutes. ---- The rush hour is 30 minutes long...
# and give them a beltway through a large rural area. ---- And you give them a beltway through a largely rural area.
# the road to nowhere. ---- A road to no where...
# Think about just how much of this money could be spent on another Potomac crossing facility or road improvements desperately needed in NOVA. ---- Just think if this money had been spent on another potomac crossing or road improvements that are desperately needed in NOVA?
# The insult added to the injury was that the rest of the state helped pay for 288 in the budget deal last year, so the debt was wiped out, said the Virginia Centrist. ---- Virginia Centrist, To add insult to injury, the rest of the state helped pay for 288 in last year's budget deal -- wiped the slate clean of debt.
# It would be very nice of you all to oblige us. ---- It was very nice of y'all to oblige us.
# But there is not much sense. ---- Didn't make much sense, though.
# The old problem is the same as it. ---- It's the same old problem.
# If you get ahead of need, you will be accused of causing sprawl. ---- If you get out ahead of the need you are accused of causing sprawl.
# If you build in a place where the need is already acute, you can 't pave your way out of congest. ---- If you build where the need is already acute, then the claim is you can't pave your way out of congestion.
# Anonymous ---- Anonymous -
# That is a fair point. ---- That's a fair point.
# 5:26 makes a good point. ---- 5:26 makes a good point.
# But this situation hammers home the validity of state audit reports that find that the CTB and VDOT are funding transportation projects based on the best lobbyists rather than a comprehensive state transportation plan. ---- However, this situation hammers home the validity of the state auditor's report finding that the CTB and VDOT fail to fund transportation projects based on a comprehensive state transportation plan, but rather, based on whoever does the best job of lobbying.
# I submit that this is a disgraceful situation that should not be tolerated. ---- I submit that this is a disgraceful situation that should not be tolerated.
# and Senator Chichester and his toady poured more money into this flawed institution, so that this has worsened. ---- Moreover, Senator Chichester and his toadies would make this worse by pouring more money into this flawed institution.
# What is the purpose of transport expenses? ---- What is the purpose of transportation - related expenditures?
# In Virginia, it was to benefit private business plans, not to serve the public interest. ---- In Virginia, it's to benefit private business plans and not to serve the public interest.
# You all are dead wrong. ---- You all are dead wrong.
# No less than Walter Stoch stated that the money for economic development is intended to be paid for by the 288. ---- No less than Walter Stoch stated that 288 money was intended to be paid from economic development money.
# Come on folks. ---- Come on folks!!
# TMT, I don't understand your point. ---- TMT : I don't understand your point.
# When you are destined for some sort of business, or not from some sort of business, when will you be stuck in traffic? ---- when was the last time you were stuck in traffic that you weren't on your way to or from some sort of business?
# The whole point of the road seems to me to be to facilitate public interest in getting into and out of private businesses. ---- It seems to me that the whole point of roads is to facilitate the public interest in getting to and from private businesses.
# Even with the sunday drive, a trip to the grandmother's location, and of course a soccer game, business support is overwhelming. ---- Then, of course there is the sunday drive, the trip to grandma's, and the soccer games, but still, the overwhelming need is to support business.
# It is no wonder that we suffer from the congest problem because our road expenditure is not matched to the increase in business or state domestic product. ---- Since our road expenditures nowhere near match the increase in business or state domestic product, it is no wonder we suffer congestion problems.
# If we recognize the primary business benefit of the road, then we should do 2 things. ---- If we recognize that roads primaarily benefit businesses then we should do two things :
# Businesses should pay more for our transport bill, of course, and incentivize them to locate where they least stress the system, even if that means more overall travel. ---- let business pay for more of our transportation bill, ( which they will pass to us, of course ) and incentivize them to locate where they put the least stress on the system, even if that means more overall travel.
# Why is it so hard to understand? ---- Why is it so hard to understand?
# The solution is a functioning human settlement pattern and a balance between the capacity of the transport system and the demand for travel generated by land use. ---- The solution is functional human settlement patterns and a balance between transport system capacity and land use generated travel deman.
# Spin all else. ---- All else is spin.
# EMR ---- EMR
# TMT said that in Virginia, it was to benefit private business plans, not to serve the public interest. ---- TMT said  In Virginia, it's to benefit private business plans and not to serve the public interest. ''
# I don't see the point of this statement, because it appears to demonize private business plans and put public interests above all else. ---- I don't see the point of this statement because it appears to demonize private business plans and put the public interest above all else.
# I think they are tightly intertwined so they are virtually the same. ---- I think they are so tightly intertwined that they are virtually one and the same.
# Local problems are obvious because this cookie dough is lumpy. ---- Obviously there are local problems because this cookie dough is lumpy,
# But if we demonize business long enough, we eventually find all of us working for the devil in aggregate. ---- but in the aggregate if we demonize business long enough we will eventually find out we all work for the Devil.
# I don't see the point of claiming a solution to the balance of a dynamic nature that will ever change. ---- I don't see there is any point in claiming as  a solution '' a balance that is dynamic and ever changing in nature.
# Even you see railings to Dulles as a positive, job center that promotes bidirectional rail demand. ---- Even you see rail to Dulles as a positive because Dulles is a job center that promotes bi-directional demand on the rail.
# I agree. ---- I agree.
# In fact, that may be all enough reason to build it on your own. ---- In fact that may be sufficient reason to build it, all by itself.
# All I said was that the exact same logic should be applied to the road. ---- All I'm saying is that the exact same logic should apply to roads :
# To maximize our investment, they should have a destination at both ends. ---- they should have destinations at both ends in order that we get maximum use out of our investment :
# We need more places to get closer to the balance we say we need. ---- we need more places in order to get closer to the balance you say we need.
# Here's a reality check. ---- Reality check here -
# I drove past Watkins Landing every morning and evening. ---- I drive past Watkins Landing every morning and evening.
# I commuted back and forth on the Huguenot Trail to my work location. ---- I commute back and forth to work on the Huguenot Trail.
# I have never seen anything remotely like a traffic flood. ---- I've never seen anything remotely resembling a  flood '' of traffic.
# It is zoned at 55 mph in a car at 75 - 100 mph in the morning. ---- It's a 55 mph zone - 75 to 100 cars in  a morning '' - over how much time?
# The Huguenot Trail is already planned to be widened because of heavy demand for development on the Chesterfield side, new schools and a whole bunch of development that existed years ago and were funneled through the Robious Road. ---- The Huguenot Trail road widening was already planned, due to the heavy demands of development on the Chesterfield side, the new schools, and a whole bunch of existing developments that were zoned years ago and at that time funneled through Robious Road.
# The 288 road was wonderful for those of us who actually used it, rather than bottlenecking Powhatan and west Chesterfield, because of its lack of roads. ---- 288, for those of us that actually use it, is wonderful - instead of Powhatan and Western Chesterfield being bottlenecked by lack of roads,
# We could develop in commerce, and work closer to our lives. ---- we can actually get some commercial development and have the ability to work closer to where we live.
# You may think that is an unrational use of land. ---- You may think that's not rational land use.
# I have no desire to live in any city. ---- I have no desire to live in any city,
# I refuse to work in the downtown area. ---- I will not work in a downtown area,
# I refuse to use mass transit that is unsafe for commuter females who work long hours that are not regular. ---- I will not use mass transit, which is not safe for female commuters that work long and irregular hours,
# and I happen to like the development of a large lot. ---- and I happen to LIKE large lot development.
# I don't understand exactly how I'm supposed to keep the horses on a 1/4 acre lot. ---- How exactly I'm supposed to keep horses on a 1/4 acre lot is beyond me.
# 1 gallon of gas could go for $10. ---- Gas could go to $ 10 a gallon
# and I still pay to live in the country. ---- and I 'd still pay to live in the country.
# Many people prefer the legitimate horse, hunt, garden and certain types of small business, making them not want to live in urban cores. ---- Many people have legitimate preferences - horses, hunting, gardening, certain types of small business - that makes them NOT want to live in an urban core.
# This infatuation with the city life truly baffles me. ---- This infatuation with city living truly baffles me.
# Anonymous 6:37 : Every right you wish to live in a country is yours. ---- Anonymous 6:37, You have every right to live in the country if that's where you wish to live.
# But you have no right to have the rest of the state underwrite the construction of a 400 million dollar highway to make shopping and getting to work easier. ---- But you don't have a right to have the rest of the state to underwrite construction of a $ 400 million highway to make it easier to shop and get to work.
# In the 288 debate, what else could be spent 400 million dollars was consistently overlooked. ---- What's consistently overlooked in the debate ovre 288 is what else that $ 400 million could have been spent on.
# The performance of Mingxia Fu and Bin Chi, female competitors of the Chinese diving team, in the first round of the preliminary 10 - meter diving competition at the Seventh World Swimming Championships held here today, was ideal, and hopeful of entering the heat. ---- The performance of the female competitors of the Chinese diving team, Mingxia Fu and Bin Chi, in the first 6 rounds of the 10 - meter platform diving preliminary competition at the Seventh World Swimming Championships held here today was ideal, and hopes of entering the heats are in sight.
# In the first round of the competition, when this reporter was dispatched, Mingxia Fu occupied the first position with a total score of 339.12 points, while Bin Chi occupied the third position with a total score of 290.19 points. ---- At the time this reporter dispatched, in the first 6 rounds of competition, Mingxia Fu and Bin Chi are temporarily occupying the first and third positions with total scores of 339.12 and 290.19 points respectively.
# Unavoidably, their hope of entering the heat is already in-sight. ---- If accidents do not occur, their hopes of entering the heats are already in sight.
# Richard, a United States competitor, occupies the second position. ---- Occupying the second position is the US competitor, Richard.
# Her performance was 303. ---- Her performance was 303.00 points.
# This morning, Lan Wei and Sheng Chen, our competitors, had already gained heat rights in a preliminary competition where a man dived a 1 meter platform. ---- In the preliminary men's 1 - meter platform diving competition this morning, our competitors Lan Wei and Sheng Chen have already gained rights to the heats.
# The preliminary women's water polo competition today resulted in a 13-7 defeat by the Hungary team to the Canadian team, a 10-9 defeat by the French team to the Brazilian team, a 10-8 defeat by the Australian team to the German team, a 10-5 defeat by the United States team to the Netherlands team, a 10-5 defeat by the Russian team to the Netherlands team, a 12-2 defeat by the Italian team to the New Zealand team. ---- The results of today's preliminary women's water - polo competition are : the Hungarian team defeated the Canadian team by 13 : 7, the French team defeated the Brazilian team by 10 : 9, the Australian team defeated the German team by 10 : 8, the Russian team defeated the Dutch team by 7 : 6, the US team defeated the Kazakhstani team by 10 : 5, and the Italian team defeated the New Zealand team by 12 : 2.
# The competition was attended by 12 teams of the total team. ---- There are 12 teams totally participating in the competition.
# ( End ) ---- ( End )

# %%
## save generated outputs
with open('test_generations.txt', 'w') as f:
    for i in range(len(list_hyp)):
        e = list_hyp[i]
        f.write(e)
        if (i != len(list_hyp)-1):
            f.write('\n')
          
## save label 
with open('test_label.txt', 'w') as f:
    for i in range(len(list_label)):
        e = list_label[i]
        f.write(e)
        if (i != len(list_label)-1):
            f.write('\n')

# %%
## BLEU SCORE
from sacrebleu import corpus_bleu

bleu = corpus_bleu(list_hyp, [list_label])
print(bleu.score)
# Out:
# 40.06338882024741

# %%
def generate(text):
    model.eval()
    input_ids = tokenizer.encode(f"translate graph to indonesian: {text}", return_tensors="pt", add_special_tokens=False)  # Batch size 1
    input_ids = input_ids.to(device)
    outputs = model.generate(input_ids, num_beams=num_beams)
    
    gen_text= tokenizer.decode(outputs[0], skip_special_tokens=True)
    return gen_text

# %%
generate("( ketik :ARG0 ( saya ) :ARG1 ( makalah ) ) )")

# %%
temp_list_hyp = []
temp_list_label = []
for e in list_hyp:
    temp_list_hyp.append(e)
for e in list_label:
    temp_list_label.append(e)
bleu = corpus_bleu(temp_list_hyp, [temp_list_label])
print(bleu.score)
